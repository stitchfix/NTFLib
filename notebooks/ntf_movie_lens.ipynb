# %%
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from ntflib import betantf

# %matplotlib inline
sns.set(style="white")

# %%
def mapper(array):
#     array = np.sort(array)
    # int_map = np.arange(len(np.unique(array))).astype(int)
    dict_map = {v:i for i, v in enumerate(np.unique(array))}
    # dict_map = dict(zip((np.unique(array), int_map))
    tmp = pd.Series(array)
    res = tmp.map(lambda x: dict_map[x])
    
    inv_dict_map = {v: k for k, v in dict_map.items()}
    return res.values, inv_dict_map

def rmse(x, y):
    return np.sqrt((x - y)**2.0).sum()

# %%
# !wget http://files.grouplens.org/datasets/movielens/ml-1m.zip
# Out:
# --2015-06-25 10:25:08--  http://files.grouplens.org/datasets/movielens/ml-1m.zip
# Resolving files.grouplens.org... 128.101.34.146
# Connecting to files.grouplens.org|128.101.34.146|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5917392 (5.6M) [application/zip]
# Saving to: 'ml-1m.zip'
#
# ml-1m.zip           100%[=====================>]   5.64M   668KB/s   in 13s
#
# 2015-06-25 10:25:22 (437 KB/s) - 'ml-1m.zip' saved [5917392/5917392]

# %%
# !unzip ml-1m.zip
# Out:
# Archive:  ml-1m.zip
#    creating: ml-1m/
#   inflating: ml-1m/movies.dat
#   inflating: ml-1m/ratings.dat
#   inflating: ml-1m/README
#   inflating: ml-1m/users.dat

# %%
ratings = pd.read_table('ml-1m/ratings.dat', sep='::', names=['UserID', 'MovieID', 'Rating', 'Timestamp'])
ratings.Timestamp = ratings.Timestamp.map(lambda x: datetime.datetime.fromtimestamp(x).strftime('%Y-%m'))
# movies = pd.read_table('ml-1m/movies.dat', sep='::', names=['MovieID', 'Title', 'Genres'])
# users = pd.read_table('ml-1m/users.dat', sep='::', names=['UserID' ,'Gender', 'Age', 'Occupation::Zip-code'])

# %%
# Converting dates to integers
ratings['UserID'], inv_uid_dict = mapper(ratings['UserID'])
ratings['MovieID'], inv_mid_dict = mapper(ratings['MovieID'])
ratings['Timestamp'], inv_ts_dict = mapper(ratings['Timestamp'])

# %%
ratings = (ratings.groupby('UserID')['Rating']
                  .mean()
                  .reset_index()
                  .rename(columns={'index': 'UserID', 'Rating':'UserID_Average'})
                  .merge(ratings, on='UserID'))
ratings['Rating_normed'] = ratings['Rating'] / ratings['UserID_Average']
ratings = (ratings.groupby('MovieID')['Rating_normed']
                  .mean()
                  .reset_index()
                  .rename(columns={'index': 'MovieID', 'Rating_normed':'MovieID_Average'})
                  .merge(ratings, on='MovieID'))
ratings['Rating_normed'] = ratings['Rating_normed'] / ratings['MovieID_Average']
ratings['Rating_multiplier'] = ratings['Rating'] / ratings['Rating_normed']

# %%
ratings.head()
# Out:
#    MovieID  MovieID_Average  UserID  UserID_Average  Rating  Timestamp  \
# 0        0         1.137663       0        4.188679       5          9
# 1        0         1.137663       5        3.901408       4          8
# 2        0         1.137663       7        3.884892       4          8
# 3        0         1.137663       8        3.735849       5          8
# 4        0         1.137663       9        4.114713       5          8
#
#    Rating_normed  Rating_multiplier
# 0       1.049251           4.765305
# 1       0.901208           4.438488
# 2       0.905039           4.419698
# 3       1.176433           4.250137
# 4       1.068112           4.681157

# %%
x_indices = ratings[['UserID', 'MovieID', 'Timestamp']].copy()
x_indices['UserID'] = x_indices['UserID'] - x_indices['UserID'].min() 
x_indices['MovieID'] = x_indices['MovieID'] - x_indices['MovieID'].min()
x_indices['Timestamp'] = x_indices['Timestamp'] - x_indices['Timestamp'].min() 

print x_indices.min()
x_indices = x_indices.values
# mean_rating = ratings['Rating'].mean() 
x_vals = ratings['Rating_normed'].values
x_multiplier = ratings['Rating_multiplier'].values
# Out:
# UserID       0
# MovieID      0
# Timestamp    0
# dtype: int64

# %%
len(ratings['MovieID'].unique())
# Out:
# 3706

# %%
ratings['MovieID'].max()
# Out:
# 3705

# %%
indices_train, indices_test, val_train, val_test, multiplier_train, multiplier_test = train_test_split(
    x_indices, x_vals, x_multiplier, test_size=0.33, random_state=30)
#     x_indices, x_vals, test_size=0.33, random_state=42)


shape_uid = len(np.unique(x_indices[:,0]))
shape_mid = len(np.unique(x_indices[:,1]))
shape_ts = len(np.unique(x_indices[:,2]))
shape = [shape_uid, shape_mid, shape_ts]
shape
# Out:
# [6040, 3706, 35]

# %%
# shape = [len(np.unique(ratings[x])) for x in ['UserID', 'MovieID', 'Timestamp']]
bnf = betantf.BetaNTF(shape, n_components=20, n_iters=100)
before = bnf.score(indices_train, val_train)
initial = bnf.impute(x_indices)
reconstructed = bnf.fit(indices_train, val_train)
after = bnf.score()
assert(after < before)
# Out:
# Update Iter 0 Factor 0 Score 49621.9
# Update Iter 0 Factor 1 Score 37133.8
# Update Iter 0 Factor 2 Score 36319.3
# Update Iter 1 Factor 0 Score 34952.7
# Update Iter 1 Factor 1 Score 33749.6
# Update Iter 1 Factor 2 Score 33516.3
# Update Iter 2 Factor 0 Score 32768.5
# Update Iter 2 Factor 1 Score 31947.7
# Update Iter 2 Factor 2 Score 31823.3
# Update Iter 3 Factor 0 Score 31298.4
# Update Iter 3 Factor 1 Score 30696.7
# Update Iter 3 Factor 2 Score 30617.6
# Update Iter 4 Factor 0 Score 30220.4
# Update Iter 4 Factor 1 Score 29758.5
# Update Iter 4 Factor 2 Score 29704.4
# Update Iter 5 Factor 0 Score 29389.1
# Update Iter 5 Factor 1 Score 29021.9
# Update Iter 5 Factor 2 Score 28983.3
# Update Iter 6 Factor 0 Score 28723.8
# Update Iter 6 Factor 1 Score 28423.8
# Update Iter 6 Factor 2 Score 28395.2
# Update Iter 7 Factor 0 Score 28175.5
# Update Iter 7 Factor 1 Score 27924.9
# Update Iter 7 Factor 2 Score 27903.1
# Update Iter 8 Factor 0 Score 27712.9
# Update Iter 8 Factor 1 Score 27499.7
# Update Iter 8 Factor 2 Score 27482.7
# Update Iter 9 Factor 0 Score 27314.9
# Update Iter 9 Factor 1 Score 27130.7
# Update Iter 9 Factor 2 Score 27117.0
# Update Iter 10 Factor 0 Score 26966.8
# Update Iter 10 Factor 1 Score 26805.4
# Update Iter 10 Factor 2 Score 26794.3
# Update Iter 11 Factor 0 Score 26658.1
# Update Iter 11 Factor 1 Score 26514.9
# Update Iter 11 Factor 2 Score 26505.8
# Update Iter 12 Factor 0 Score 26380.9
# Update Iter 12 Factor 1 Score 26252.6
# Update Iter 12 Factor 2 Score 26245.0
# Update Iter 13 Factor 0 Score 26129.4
# Update Iter 13 Factor 1 Score 26013.4
# Update Iter 13 Factor 2 Score 26006.9
# Update Iter 14 Factor 0 Score 25899.1
# Update Iter 14 Factor 1 Score 25793.3
# Update Iter 14 Factor 2 Score 25787.7
# Update Iter 15 Factor 0 Score 25686.5
# Update Iter 15 Factor 1 Score 25589.2
# Update Iter 15 Factor 2 Score 25584.4
# Update Iter 16 Factor 0 Score 25488.8
# Update Iter 16 Factor 1 Score 25398.7
# Update Iter 16 Factor 2 Score 25394.5
# Update Iter 17 Factor 0 Score 25303.7
# Update Iter 17 Factor 1 Score 25219.8
# Update Iter 17 Factor 2 Score 25216.0
# Update Iter 18 Factor 0 Score 25129.5
# Update Iter 18 Factor 1 Score 25050.9
# Update Iter 18 Factor 2 Score 25047.5
# Update Iter 19 Factor 0 Score 24964.7
# Update Iter 19 Factor 1 Score 24890.7
# Update Iter 19 Factor 2 Score 24887.6
# Update Iter 20 Factor 0 Score 24808.0
# Update Iter 20 Factor 1 Score 24738.0
# Update Iter 20 Factor 2 Score 24735.2
# Update Iter 21 Factor 0 Score 24658.5
# Update Iter 21 Factor 1 Score 24591.9
# Update Iter 21 Factor 2 Score 24589.4
# Update Iter 22 Factor 0 Score 24515.3
# Update Iter 22 Factor 1 Score 24451.8
# Update Iter 22 Factor 2 Score 24449.4
# Update Iter 23 Factor 0 Score 24377.6
# Update Iter 23 Factor 1 Score 24316.8
# Update Iter 23 Factor 2 Score 24314.6
# Update Iter 24 Factor 0 Score 24244.9
# Update Iter 24 Factor 1 Score 24186.6
# Update Iter 24 Factor 2 Score 24184.5
# Update Iter 25 Factor 0 Score 24116.7
# Update Iter 25 Factor 1 Score 24060.5
# Update Iter 25 Factor 2 Score 24058.6
# Update Iter 26 Factor 0 Score 23992.5
# Update Iter 26 Factor 1 Score 23938.2
# Update Iter 26 Factor 2 Score 23936.4
# Update Iter 27 Factor 0 Score 23872.0
# Update Iter 27 Factor 1 Score 23819.4
# Update Iter 27 Factor 2 Score 23817.7
# Update Iter 28 Factor 0 Score 23754.7
# Update Iter 28 Factor 1 Score 23703.7
# Update Iter 28 Factor 2 Score 23702.1
# Update Iter 29 Factor 0 Score 23640.5
# Update Iter 29 Factor 1 Score 23590.9
# Update Iter 29 Factor 2 Score 23589.3
# Update Iter 30 Factor 0 Score 23529.0
# Update Iter 30 Factor 1 Score 23480.7
# Update Iter 30 Factor 2 Score 23479.2
# Update Iter 31 Factor 0 Score 23420.1
# Update Iter 31 Factor 1 Score 23373.0
# Update Iter 31 Factor 2 Score 23371.5
# Update Iter 32 Factor 0 Score 23313.5
# Update Iter 32 Factor 1 Score 23267.5
# Update Iter 32 Factor 2 Score 23266.0
# Update Iter 33 Factor 0 Score 23209.1
# Update Iter 33 Factor 1 Score 23164.0
# Update Iter 33 Factor 2 Score 23162.6
# Update Iter 34 Factor 0 Score 23106.6
# Update Iter 34 Factor 1 Score 23062.5
# Update Iter 34 Factor 2 Score 23061.1
# Update Iter 35 Factor 0 Score 23006.1
# Update Iter 35 Factor 1 Score 22962.8
# Update Iter 35 Factor 2 Score 22961.4
# Update Iter 36 Factor 0 Score 22907.2
# Update Iter 36 Factor 1 Score 22864.8
# Update Iter 36 Factor 2 Score 22863.4
# Update Iter 37 Factor 0 Score 22810.0
# Update Iter 37 Factor 1 Score 22768.3
# Update Iter 37 Factor 2 Score 22767.0
# Update Iter 38 Factor 0 Score 22714.4
# Update Iter 38 Factor 1 Score 22673.3
# Update Iter 38 Factor 2 Score 22672.0
# Update Iter 39 Factor 0 Score 22620.2
# Update Iter 39 Factor 1 Score 22579.8
# Update Iter 39 Factor 2 Score 22578.5
# Update Iter 40 Factor 0 Score 22527.3
# Update Iter 40 Factor 1 Score 22487.5
# Update Iter 40 Factor 2 Score 22486.2
# Update Iter 41 Factor 0 Score 22435.8
# Update Iter 41 Factor 1 Score 22396.5
# Update Iter 41 Factor 2 Score 22395.3
# Update Iter 42 Factor 0 Score 22345.5
# Update Iter 42 Factor 1 Score 22306.8
# Update Iter 42 Factor 2 Score 22305.5
# Update Iter 43 Factor 0 Score 22256.4
# Update Iter 43 Factor 1 Score 22218.2
# Update Iter 43 Factor 2 Score 22216.9
# Update Iter 44 Factor 0 Score 22168.4
# Update Iter 44 Factor 1 Score 22130.7
# Update Iter 44 Factor 2 Score 22129.4
# Update Iter 45 Factor 0 Score 22081.5
# Update Iter 45 Factor 1 Score 22044.3
# Update Iter 45 Factor 2 Score 22043.0
# Update Iter 46 Factor 0 Score 21995.7
# Update Iter 46 Factor 1 Score 21958.9
# Update Iter 46 Factor 2 Score 21957.7
# Update Iter 47 Factor 0 Score 21910.9
# Update Iter 47 Factor 1 Score 21874.6
# Update Iter 47 Factor 2 Score 21873.3
# Update Iter 48 Factor 0 Score 21827.1
# Update Iter 48 Factor 1 Score 21791.2
# Update Iter 48 Factor 2 Score 21790.0
# Update Iter 49 Factor 0 Score 21744.3
# Update Iter 49 Factor 1 Score 21708.9
# Update Iter 49 Factor 2 Score 21707.6
# Update Iter 50 Factor 0 Score 21662.5
# Update Iter 50 Factor 1 Score 21627.5
# Update Iter 50 Factor 2 Score 21626.2
# Update Iter 51 Factor 0 Score 21581.6
# Update Iter 51 Factor 1 Score 21547.0
# Update Iter 51 Factor 2 Score 21545.7
# Update Iter 52 Factor 0 Score 21501.7
# Update Iter 52 Factor 1 Score 21467.5
# Update Iter 52 Factor 2 Score 21466.2
# Update Iter 53 Factor 0 Score 21422.7
# Update Iter 53 Factor 1 Score 21388.9
# Update Iter 53 Factor 2 Score 21387.6
# Update Iter 54 Factor 0 Score 21344.7
# Update Iter 54 Factor 1 Score 21311.3
# Update Iter 54 Factor 2 Score 21310.0
# Update Iter 55 Factor 0 Score 21267.5
# Update Iter 55 Factor 1 Score 21234.6
# Update Iter 55 Factor 2 Score 21233.3
# Update Iter 56 Factor 0 Score 21191.4
# Update Iter 56 Factor 1 Score 21158.8
# Update Iter 56 Factor 2 Score 21157.5
# Update Iter 57 Factor 0 Score 21116.1
# Update Iter 57 Factor 1 Score 21084.0
# Update Iter 57 Factor 2 Score 21082.7
# Update Iter 58 Factor 0 Score 21041.8
# Update Iter 58 Factor 1 Score 21010.1
# Update Iter 58 Factor 2 Score 21008.8
# Update Iter 59 Factor 0 Score 20968.4
# Update Iter 59 Factor 1 Score 20937.1
# Update Iter 59 Factor 2 Score 20935.8
# Update Iter 60 Factor 0 Score 20896.0
# Update Iter 60 Factor 1 Score 20865.1
# Update Iter 60 Factor 2 Score 20863.8
# Update Iter 61 Factor 0 Score 20824.5
# Update Iter 61 Factor 1 Score 20794.1
# Update Iter 61 Factor 2 Score 20792.8
# Update Iter 62 Factor 0 Score 20754.0
# Update Iter 62 Factor 1 Score 20724.0
# Update Iter 62 Factor 2 Score 20722.7
# Update Iter 63 Factor 0 Score 20684.5
# Update Iter 63 Factor 1 Score 20654.9
# Update Iter 63 Factor 2 Score 20653.6
# Update Iter 64 Factor 0 Score 20616.0
# Update Iter 64 Factor 1 Score 20586.8
# Update Iter 64 Factor 2 Score 20585.5
# Update Iter 65 Factor 0 Score 20548.4
# Update Iter 65 Factor 1 Score 20519.7
# Update Iter 65 Factor 2 Score 20518.4
# Update Iter 66 Factor 0 Score 20481.8
# Update Iter 66 Factor 1 Score 20453.5
# Update Iter 66 Factor 2 Score 20452.2
# Update Iter 67 Factor 0 Score 20416.2
# Update Iter 67 Factor 1 Score 20388.4
# Update Iter 67 Factor 2 Score 20387.1
# Update Iter 68 Factor 0 Score 20351.6
# Update Iter 68 Factor 1 Score 20324.3
# Update Iter 68 Factor 2 Score 20323.0
# Update Iter 69 Factor 0 Score 20288.0
# Update Iter 69 Factor 1 Score 20261.1
# Update Iter 69 Factor 2 Score 20259.9
# Update Iter 70 Factor 0 Score 20225.5
# Update Iter 70 Factor 1 Score 20199.0
# Update Iter 70 Factor 2 Score 20197.8
# Update Iter 71 Factor 0 Score 20163.9
# Update Iter 71 Factor 1 Score 20137.9
# Update Iter 71 Factor 2 Score 20136.7
# Update Iter 72 Factor 0 Score 20103.4
# Update Iter 72 Factor 1 Score 20077.8
# Update Iter 72 Factor 2 Score 20076.6
# Update Iter 73 Factor 0 Score 20043.8
# Update Iter 73 Factor 1 Score 20018.7
# Update Iter 73 Factor 2 Score 20017.5
# Update Iter 74 Factor 0 Score 19985.2
# Update Iter 74 Factor 1 Score 19960.6
# Update Iter 74 Factor 2 Score 19959.4
# Update Iter 75 Factor 0 Score 19927.7
# Update Iter 75 Factor 1 Score 19903.5
# Update Iter 75 Factor 2 Score 19902.3
# Update Iter 76 Factor 0 Score 19871.1
# Update Iter 76 Factor 1 Score 19847.4
# Update Iter 76 Factor 2 Score 19846.2
# Update Iter 77 Factor 0 Score 19815.6
# Update Iter 77 Factor 1 Score 19792.3
# Update Iter 77 Factor 2 Score 19791.0
# Update Iter 78 Factor 0 Score 19760.9
# Update Iter 78 Factor 1 Score 19738.1
# Update Iter 78 Factor 2 Score 19736.9
# Update Iter 79 Factor 0 Score 19707.3
# Update Iter 79 Factor 1 Score 19684.9
# Update Iter 79 Factor 2 Score 19683.7
# Update Iter 80 Factor 0 Score 19654.6
# Update Iter 80 Factor 1 Score 19632.7
# Update Iter 80 Factor 2 Score 19631.5
# Update Iter 81 Factor 0 Score 19602.9
# Update Iter 81 Factor 1 Score 19581.4
# Update Iter 81 Factor 2 Score 19580.2
# Update Iter 82 Factor 0 Score 19552.1
# Update Iter 82 Factor 1 Score 19531.0
# Update Iter 82 Factor 2 Score 19529.8
# Update Iter 83 Factor 0 Score 19502.2
# Update Iter 83 Factor 1 Score 19481.5
# Update Iter 83 Factor 2 Score 19480.4
# Update Iter 84 Factor 0 Score 19453.3
# Update Iter 84 Factor 1 Score 19432.9
# Update Iter 84 Factor 2 Score 19431.8
# Update Iter 85 Factor 0 Score 19405.2
# Update Iter 85 Factor 1 Score 19385.3
# Update Iter 85 Factor 2 Score 19384.1
# Update Iter 86 Factor 0 Score 19358.0
# Update Iter 86 Factor 1 Score 19338.5
# Update Iter 86 Factor 2 Score 19337.3
# Update Iter 87 Factor 0 Score 19311.6
# Update Iter 87 Factor 1 Score 19292.5
# Update Iter 87 Factor 2 Score 19291.4
# Update Iter 88 Factor 0 Score 19266.1
# Update Iter 88 Factor 1 Score 19247.4
# Update Iter 88 Factor 2 Score 19246.3
# Update Iter 89 Factor 0 Score 19221.5
# Update Iter 89 Factor 1 Score 19203.1
# Update Iter 89 Factor 2 Score 19202.0
# Update Iter 90 Factor 0 Score 19177.6
# Update Iter 90 Factor 1 Score 19159.5
# Update Iter 90 Factor 2 Score 19158.5
# Update Iter 91 Factor 0 Score 19134.5
# Update Iter 91 Factor 1 Score 19116.8
# Update Iter 91 Factor 2 Score 19115.8
# Update Iter 92 Factor 0 Score 19092.2
# Update Iter 92 Factor 1 Score 19074.9
# Update Iter 92 Factor 2 Score 19073.8
# Update Iter 93 Factor 0 Score 19050.7
# Update Iter 93 Factor 1 Score 19033.7
# Update Iter 93 Factor 2 Score 19032.6
# Update Iter 94 Factor 0 Score 19009.9
# Update Iter 94 Factor 1 Score 18993.2
# Update Iter 94 Factor 2 Score 18992.2
# Update Iter 95 Factor 0 Score 18969.8
# Update Iter 95 Factor 1 Score 18953.5
# Update Iter 95 Factor 2 Score 18952.5
# Update Iter 96 Factor 0 Score 18930.5
# Update Iter 96 Factor 1 Score 18914.4
# Update Iter 96 Factor 2 Score 18913.4
# Update Iter 97 Factor 0 Score 18891.8
# Update Iter 97 Factor 1 Score 18876.0
# Update Iter 97 Factor 2 Score 18875.1
# Update Iter 98 Factor 0 Score 18853.8
# Update Iter 98 Factor 1 Score 18838.4
# Update Iter 98 Factor 2 Score 18837.4
# Update Iter 99 Factor 0 Score 18816.5
# Update Iter 99 Factor 1 Score 18801.3
# Update Iter 99 Factor 2 Score 18800.3

# %%
reconstructed = bnf.fit(indices_train, val_train)
# Out:
# Update Iter 0 Factor 0 Score 16824.3
# Update Iter 0 Factor 1 Score 16820.2
# Update Iter 0 Factor 2 Score 16819.9
# Update Iter 1 Factor 0 Score 16813.8
# Update Iter 1 Factor 1 Score 16809.8
# Update Iter 1 Factor 2 Score 16809.5
# Update Iter 2 Factor 0 Score 16803.5
# Update Iter 2 Factor 1 Score 16799.5
# Update Iter 2 Factor 2 Score 16799.1
# Update Iter 3 Factor 0 Score 16793.2
# Update Iter 3 Factor 1 Score 16789.3
# Update Iter 3 Factor 2 Score 16788.9
# Update Iter 4 Factor 0 Score 16783.0
# Update Iter 4 Factor 1 Score 16779.1
# Update Iter 4 Factor 2 Score 16778.8
# Update Iter 5 Factor 0 Score 16772.9
# Update Iter 5 Factor 1 Score 16769.1
# Update Iter 5 Factor 2 Score 16768.7
# Update Iter 6 Factor 0 Score 16762.9
# Update Iter 6 Factor 1 Score 16759.1
# Update Iter 6 Factor 2 Score 16758.8
# Update Iter 7 Factor 0 Score 16753.0
# Update Iter 7 Factor 1 Score 16749.3
# Update Iter 7 Factor 2 Score 16748.9
# Update Iter 8 Factor 0 Score 16743.2
# Update Iter 8 Factor 1 Score 16739.5
# Update Iter 8 Factor 2 Score 16739.2
# Update Iter 9 Factor 0 Score 16733.5
# Update Iter 9 Factor 1 Score 16729.8
# Update Iter 9 Factor 2 Score 16729.5
# Update Iter 10 Factor 0 Score 16723.9
# Update Iter 10 Factor 1 Score 16720.2
# Update Iter 10 Factor 2 Score 16719.9
# Update Iter 11 Factor 0 Score 16714.4
# Update Iter 11 Factor 1 Score 16710.7
# Update Iter 11 Factor 2 Score 16710.4
# Update Iter 12 Factor 0 Score 16704.9
# Update Iter 12 Factor 1 Score 16701.3
# Update Iter 12 Factor 2 Score 16701.0
# Update Iter 13 Factor 0 Score 16695.5
# Update Iter 13 Factor 1 Score 16692.0
# Update Iter 13 Factor 2 Score 16691.6
# Update Iter 14 Factor 0 Score 16686.2
# Update Iter 14 Factor 1 Score 16682.7
# Update Iter 14 Factor 2 Score 16682.4
# Update Iter 15 Factor 0 Score 16677.0
# Update Iter 15 Factor 1 Score 16673.5
# Update Iter 15 Factor 2 Score 16673.2
# Update Iter 16 Factor 0 Score 16667.9
# Update Iter 16 Factor 1 Score 16664.5
# Update Iter 16 Factor 2 Score 16664.1
# Update Iter 17 Factor 0 Score 16658.9
# Update Iter 17 Factor 1 Score 16655.4
# Update Iter 17 Factor 2 Score 16655.1
# Update Iter 18 Factor 0 Score 16649.9
# Update Iter 18 Factor 1 Score 16646.5
# Update Iter 18 Factor 2 Score 16646.2
# Update Iter 19 Factor 0 Score 16641.0
# Update Iter 19 Factor 1 Score 16637.7
# Update Iter 19 Factor 2 Score 16637.4
# Update Iter 20 Factor 0 Score 16632.2
# Update Iter 20 Factor 1 Score 16628.9
# Update Iter 20 Factor 2 Score 16628.6
# Update Iter 21 Factor 0 Score 16623.5
# Update Iter 21 Factor 1 Score 16620.2
# Update Iter 21 Factor 2 Score 16619.9
# Update Iter 22 Factor 0 Score 16614.9
# Update Iter 22 Factor 1 Score 16611.6
# Update Iter 22 Factor 2 Score 16611.3
# Update Iter 23 Factor 0 Score 16606.3
# Update Iter 23 Factor 1 Score 16603.0
# Update Iter 23 Factor 2 Score 16602.7
# Update Iter 24 Factor 0 Score 16597.8
# Update Iter 24 Factor 1 Score 16594.6
# Update Iter 24 Factor 2 Score 16594.3
# Update Iter 25 Factor 0 Score 16589.4
# Update Iter 25 Factor 1 Score 16586.2
# Update Iter 25 Factor 2 Score 16585.9
# Update Iter 26 Factor 0 Score 16581.0
# Update Iter 26 Factor 1 Score 16577.9
# Update Iter 26 Factor 2 Score 16577.6
# Update Iter 27 Factor 0 Score 16572.7
# Update Iter 27 Factor 1 Score 16569.6
# Update Iter 27 Factor 2 Score 16569.3
# Update Iter 28 Factor 0 Score 16564.5
# Update Iter 28 Factor 1 Score 16561.4
# Update Iter 28 Factor 2 Score 16561.1
# Update Iter 29 Factor 0 Score 16556.4
# Update Iter 29 Factor 1 Score 16553.3
# Update Iter 29 Factor 2 Score 16553.0
# Update Iter 30 Factor 0 Score 16548.3
# Update Iter 30 Factor 1 Score 16545.3
# Update Iter 30 Factor 2 Score 16545.0
# Update Iter 31 Factor 0 Score 16540.3
# Update Iter 31 Factor 1 Score 16537.3
# Update Iter 31 Factor 2 Score 16537.0
# Update Iter 32 Factor 0 Score 16532.4
# Update Iter 32 Factor 1 Score 16529.4
# Update Iter 32 Factor 2 Score 16529.1
# Update Iter 33 Factor 0 Score 16524.5
# Update Iter 33 Factor 1 Score 16521.6
# Update Iter 33 Factor 2 Score 16521.3
# Update Iter 34 Factor 0 Score 16516.7
# Update Iter 34 Factor 1 Score 16513.8
# Update Iter 34 Factor 2 Score 16513.5
# Update Iter 35 Factor 0 Score 16509.0
# Update Iter 35 Factor 1 Score 16506.1
# Update Iter 35 Factor 2 Score 16505.8
# Update Iter 36 Factor 0 Score 16501.3
# Update Iter 36 Factor 1 Score 16498.4
# Update Iter 36 Factor 2 Score 16498.2
# Update Iter 37 Factor 0 Score 16493.7
# Update Iter 37 Factor 1 Score 16490.9
# Update Iter 37 Factor 2 Score 16490.6
# Update Iter 38 Factor 0 Score 16486.2
# Update Iter 38 Factor 1 Score 16483.3
# Update Iter 38 Factor 2 Score 16483.1
# Update Iter 39 Factor 0 Score 16478.7
# Update Iter 39 Factor 1 Score 16475.9
# Update Iter 39 Factor 2 Score 16475.6
# Update Iter 40 Factor 0 Score 16471.3
# Update Iter 40 Factor 1 Score 16468.5
# Update Iter 40 Factor 2 Score 16468.2
# Update Iter 41 Factor 0 Score 16464.0
# Update Iter 41 Factor 1 Score 16461.2
# Update Iter 41 Factor 2 Score 16460.9
# Update Iter 42 Factor 0 Score 16456.7
# Update Iter 42 Factor 1 Score 16453.9
# Update Iter 42 Factor 2 Score 16453.7
# Update Iter 43 Factor 0 Score 16449.4
# Update Iter 43 Factor 1 Score 16446.7
# Update Iter 43 Factor 2 Score 16446.4
# Update Iter 44 Factor 0 Score 16442.3
# Update Iter 44 Factor 1 Score 16439.6
# Update Iter 44 Factor 2 Score 16439.3
# Update Iter 45 Factor 0 Score 16435.2
# Update Iter 45 Factor 1 Score 16432.5
# Update Iter 45 Factor 2 Score 16432.2
# Update Iter 46 Factor 0 Score 16428.1
# Update Iter 46 Factor 1 Score 16425.4
# Update Iter 46 Factor 2 Score 16425.2
# Update Iter 47 Factor 0 Score 16421.1
# Update Iter 47 Factor 1 Score 16418.5
# Update Iter 47 Factor 2 Score 16418.2
# Update Iter 48 Factor 0 Score 16414.2
# Update Iter 48 Factor 1 Score 16411.6
# Update Iter 48 Factor 2 Score 16411.3
# Update Iter 49 Factor 0 Score 16407.3
# Update Iter 49 Factor 1 Score 16404.7
# Update Iter 49 Factor 2 Score 16404.4
# Update Iter 50 Factor 0 Score 16400.5
# Update Iter 50 Factor 1 Score 16397.9
# Update Iter 50 Factor 2 Score 16397.6
# Update Iter 51 Factor 0 Score 16393.7
# Update Iter 51 Factor 1 Score 16391.1
# Update Iter 51 Factor 2 Score 16390.9
# Update Iter 52 Factor 0 Score 16387.0
# Update Iter 52 Factor 1 Score 16384.5
# Update Iter 52 Factor 2 Score 16384.2
# Update Iter 53 Factor 0 Score 16380.3
# Update Iter 53 Factor 1 Score 16377.8
# Update Iter 53 Factor 2 Score 16377.6
# Update Iter 54 Factor 0 Score 16373.7
# Update Iter 54 Factor 1 Score 16371.2
# Update Iter 54 Factor 2 Score 16371.0
# Update Iter 55 Factor 0 Score 16367.2
# Update Iter 55 Factor 1 Score 16364.7
# Update Iter 55 Factor 2 Score 16364.5
# Update Iter 56 Factor 0 Score 16360.7
# Update Iter 56 Factor 1 Score 16358.2
# Update Iter 56 Factor 2 Score 16358.0
# Update Iter 57 Factor 0 Score 16354.2
# Update Iter 57 Factor 1 Score 16351.8
# Update Iter 57 Factor 2 Score 16351.5
# Update Iter 58 Factor 0 Score 16347.8
# Update Iter 58 Factor 1 Score 16345.4
# Update Iter 58 Factor 2 Score 16345.2
# Update Iter 59 Factor 0 Score 16341.5
# Update Iter 59 Factor 1 Score 16339.1
# Update Iter 59 Factor 2 Score 16338.8
# Update Iter 60 Factor 0 Score 16335.2
# Update Iter 60 Factor 1 Score 16332.8
# Update Iter 60 Factor 2 Score 16332.6
# Update Iter 61 Factor 0 Score 16328.9
# Update Iter 61 Factor 1 Score 16326.6
# Update Iter 61 Factor 2 Score 16326.3
# Update Iter 62 Factor 0 Score 16322.7
# Update Iter 62 Factor 1 Score 16320.4
# Update Iter 62 Factor 2 Score 16320.2
# Update Iter 63 Factor 0 Score 16316.6
# Update Iter 63 Factor 1 Score 16314.3
# Update Iter 63 Factor 2 Score 16314.0
# Update Iter 64 Factor 0 Score 16310.5
# Update Iter 64 Factor 1 Score 16308.2
# Update Iter 64 Factor 2 Score 16307.9
# Update Iter 65 Factor 0 Score 16304.4
# Update Iter 65 Factor 1 Score 16302.1
# Update Iter 65 Factor 2 Score 16301.9
# Update Iter 66 Factor 0 Score 16298.4
# Update Iter 66 Factor 1 Score 16296.1
# Update Iter 66 Factor 2 Score 16295.9
# Update Iter 67 Factor 0 Score 16292.4
# Update Iter 67 Factor 1 Score 16290.2
# Update Iter 67 Factor 2 Score 16290.0
# Update Iter 68 Factor 0 Score 16286.5
# Update Iter 68 Factor 1 Score 16284.3
# Update Iter 68 Factor 2 Score 16284.1
# Update Iter 69 Factor 0 Score 16280.6
# Update Iter 69 Factor 1 Score 16278.5
# Update Iter 69 Factor 2 Score 16278.2
# Update Iter 70 Factor 0 Score 16274.8
# Update Iter 70 Factor 1 Score 16272.6
# Update Iter 70 Factor 2 Score 16272.4
# Update Iter 71 Factor 0 Score 16269.0
# Update Iter 71 Factor 1 Score 16266.9
# Update Iter 71 Factor 2 Score 16266.7
# Update Iter 72 Factor 0 Score 16263.3
# Update Iter 72 Factor 1 Score 16261.2
# Update Iter 72 Factor 2 Score 16260.9
# Update Iter 73 Factor 0 Score 16257.6
# Update Iter 73 Factor 1 Score 16255.5
# Update Iter 73 Factor 2 Score 16255.3
# Update Iter 74 Factor 0 Score 16252.0
# Update Iter 74 Factor 1 Score 16249.9
# Update Iter 74 Factor 2 Score 16249.6
# Update Iter 75 Factor 0 Score 16246.4
# Update Iter 75 Factor 1 Score 16244.3
# Update Iter 75 Factor 2 Score 16244.0
# Update Iter 76 Factor 0 Score 16240.8
# Update Iter 76 Factor 1 Score 16238.7
# Update Iter 76 Factor 2 Score 16238.5
# Update Iter 77 Factor 0 Score 16235.3
# Update Iter 77 Factor 1 Score 16233.2
# Update Iter 77 Factor 2 Score 16233.0
# Update Iter 78 Factor 0 Score 16229.8
# Update Iter 78 Factor 1 Score 16227.7
# Update Iter 78 Factor 2 Score 16227.5
# Update Iter 79 Factor 0 Score 16224.3
# Update Iter 79 Factor 1 Score 16222.3
# Update Iter 79 Factor 2 Score 16222.1
# Update Iter 80 Factor 0 Score 16218.9
# Update Iter 80 Factor 1 Score 16216.9
# Update Iter 80 Factor 2 Score 16216.7
# Update Iter 81 Factor 0 Score 16213.6
# Update Iter 81 Factor 1 Score 16211.6
# Update Iter 81 Factor 2 Score 16211.4
# Update Iter 82 Factor 0 Score 16208.2
# Update Iter 82 Factor 1 Score 16206.3
# Update Iter 82 Factor 2 Score 16206.1
# Update Iter 83 Factor 0 Score 16203.0
# Update Iter 83 Factor 1 Score 16201.0
# Update Iter 83 Factor 2 Score 16200.8
# Update Iter 84 Factor 0 Score 16197.7
# Update Iter 84 Factor 1 Score 16195.8
# Update Iter 84 Factor 2 Score 16195.6
# Update Iter 85 Factor 0 Score 16192.5
# Update Iter 85 Factor 1 Score 16190.6
# Update Iter 85 Factor 2 Score 16190.4
# Update Iter 86 Factor 0 Score 16187.3
# Update Iter 86 Factor 1 Score 16185.4
# Update Iter 86 Factor 2 Score 16185.2
# Update Iter 87 Factor 0 Score 16182.2
# Update Iter 87 Factor 1 Score 16180.3
# Update Iter 87 Factor 2 Score 16180.1
# Update Iter 88 Factor 0 Score 16177.1
# Update Iter 88 Factor 1 Score 16175.2
# Update Iter 88 Factor 2 Score 16175.0
# Update Iter 89 Factor 0 Score 16172.1
# Update Iter 89 Factor 1 Score 16170.2
# Update Iter 89 Factor 2 Score 16170.0
# Update Iter 90 Factor 0 Score 16167.0
# Update Iter 90 Factor 1 Score 16165.2
# Update Iter 90 Factor 2 Score 16165.0
# Update Iter 91 Factor 0 Score 16162.0
# Update Iter 91 Factor 1 Score 16160.2
# Update Iter 91 Factor 2 Score 16160.0
# Update Iter 92 Factor 0 Score 16157.1
# Update Iter 92 Factor 1 Score 16155.3
# Update Iter 92 Factor 2 Score 16155.1
# Update Iter 93 Factor 0 Score 16152.2
# Update Iter 93 Factor 1 Score 16150.3
# Update Iter 93 Factor 2 Score 16150.2
# Update Iter 94 Factor 0 Score 16147.3
# Update Iter 94 Factor 1 Score 16145.5
# Update Iter 94 Factor 2 Score 16145.3
# Update Iter 95 Factor 0 Score 16142.5
# Update Iter 95 Factor 1 Score 16140.6
# Update Iter 95 Factor 2 Score 16140.5
# Update Iter 96 Factor 0 Score 16137.6
# Update Iter 96 Factor 1 Score 16135.8
# Update Iter 96 Factor 2 Score 16135.7
# Update Iter 97 Factor 0 Score 16132.9
# Update Iter 97 Factor 1 Score 16131.1
# Update Iter 97 Factor 2 Score 16130.9
# Update Iter 98 Factor 0 Score 16128.1
# Update Iter 98 Factor 1 Score 16126.3
# Update Iter 98 Factor 2 Score 16126.2
# Update Iter 99 Factor 0 Score 16123.4
# Update Iter 99 Factor 1 Score 16121.6
# Update Iter 99 Factor 2 Score 16121.5

# %%
bnf.n_iters = 1000
reconstructed = bnf.fit(indices_train, val_train)
# Out:
# Update Iter 0 Factor 0 Score 16118.7
# Update Iter 0 Factor 1 Score 16117.0
# Update Iter 0 Factor 2 Score 16116.8
# Update Iter 1 Factor 0 Score 16114.1
# Update Iter 1 Factor 1 Score 16112.3
# Update Iter 1 Factor 2 Score 16112.2
# Update Iter 2 Factor 0 Score 16109.4
# Update Iter 2 Factor 1 Score 16107.7
# Update Iter 2 Factor 2 Score 16107.6
# Update Iter 3 Factor 0 Score 16104.9
# Update Iter 3 Factor 1 Score 16103.2
# Update Iter 3 Factor 2 Score 16103.0
# Update Iter 4 Factor 0 Score 16100.3
# Update Iter 4 Factor 1 Score 16098.6
# Update Iter 4 Factor 2 Score 16098.4
# Update Iter 5 Factor 0 Score 16095.8
# Update Iter 5 Factor 1 Score 16094.1
# Update Iter 5 Factor 2 Score 16093.9
# Update Iter 6 Factor 0 Score 16091.3
# Update Iter 6 Factor 1 Score 16089.6
# Update Iter 6 Factor 2 Score 16089.5
# Update Iter 7 Factor 0 Score 16086.8
# Update Iter 7 Factor 1 Score 16085.2
# Update Iter 7 Factor 2 Score 16085.0
# Update Iter 8 Factor 0 Score 16082.4
# Update Iter 8 Factor 1 Score 16080.7
# Update Iter 8 Factor 2 Score 16080.6
# Update Iter 9 Factor 0 Score 16078.0
# Update Iter 9 Factor 1 Score 16076.4
# Update Iter 9 Factor 2 Score 16076.2
# Update Iter 10 Factor 0 Score 16073.6
# Update Iter 10 Factor 1 Score 16072.0
# Update Iter 10 Factor 2 Score 16071.8
# Update Iter 11 Factor 0 Score 16069.3
# Update Iter 11 Factor 1 Score 16067.7
# Update Iter 11 Factor 2 Score 16067.5
# Update Iter 12 Factor 0 Score 16065.0
# Update Iter 12 Factor 1 Score 16063.4
# Update Iter 12 Factor 2 Score 16063.2
# Update Iter 13 Factor 0 Score 16060.7
# Update Iter 13 Factor 1 Score 16059.1
# Update Iter 13 Factor 2 Score 16058.9
# Update Iter 14 Factor 0 Score 16056.4
# Update Iter 14 Factor 1 Score 16054.8
# Update Iter 14 Factor 2 Score 16054.7
# Update Iter 15 Factor 0 Score 16052.2
# Update Iter 15 Factor 1 Score 16050.6
# Update Iter 15 Factor 2 Score 16050.5
# Update Iter 16 Factor 0 Score 16048.0
# Update Iter 16 Factor 1 Score 16046.4
# Update Iter 16 Factor 2 Score 16046.3
# Update Iter 17 Factor 0 Score 16043.8
# Update Iter 17 Factor 1 Score 16042.3
# Update Iter 17 Factor 2 Score 16042.1
# Update Iter 18 Factor 0 Score 16039.7
# Update Iter 18 Factor 1 Score 16038.1
# Update Iter 18 Factor 2 Score 16038.0
# Update Iter 19 Factor 0 Score 16035.5
# Update Iter 19 Factor 1 Score 16034.0
# Update Iter 19 Factor 2 Score 16033.8
# Update Iter 20 Factor 0 Score 16031.4
# Update Iter 20 Factor 1 Score 16029.9
# Update Iter 20 Factor 2 Score 16029.8
# Update Iter 21 Factor 0 Score 16027.4
# Update Iter 21 Factor 1 Score 16025.9
# Update Iter 21 Factor 2 Score 16025.7
# Update Iter 22 Factor 0 Score 16023.3
# Update Iter 22 Factor 1 Score 16021.8
# Update Iter 22 Factor 2 Score 16021.7
# Update Iter 23 Factor 0 Score 16019.3
# Update Iter 23 Factor 1 Score 16017.8
# Update Iter 23 Factor 2 Score 16017.7
# Update Iter 24 Factor 0 Score 16015.3
# Update Iter 24 Factor 1 Score 16013.8
# Update Iter 24 Factor 2 Score 16013.7
# Update Iter 25 Factor 0 Score 16011.4
# Update Iter 25 Factor 1 Score 16009.9
# Update Iter 25 Factor 2 Score 16009.7
# Update Iter 26 Factor 0 Score 16007.4
# Update Iter 26 Factor 1 Score 16006.0
# Update Iter 26 Factor 2 Score 16005.8
# Update Iter 27 Factor 0 Score 16003.5
# Update Iter 27 Factor 1 Score 16002.0
# Update Iter 27 Factor 2 Score 16001.9
# Update Iter 28 Factor 0 Score 15999.6
# Update Iter 28 Factor 1 Score 15998.2
# Update Iter 28 Factor 2 Score 15998.0
# Update Iter 29 Factor 0 Score 15995.7
# Update Iter 29 Factor 1 Score 15994.3
# Update Iter 29 Factor 2 Score 15994.2
# Update Iter 30 Factor 0 Score 15991.9
# Update Iter 30 Factor 1 Score 15990.5
# Update Iter 30 Factor 2 Score 15990.3
# Update Iter 31 Factor 0 Score 15988.1
# Update Iter 31 Factor 1 Score 15986.7
# Update Iter 31 Factor 2 Score 15986.5
# Update Iter 32 Factor 0 Score 15984.3
# Update Iter 32 Factor 1 Score 15982.9
# Update Iter 32 Factor 2 Score 15982.7
# Update Iter 33 Factor 0 Score 15980.5
# Update Iter 33 Factor 1 Score 15979.1
# Update Iter 33 Factor 2 Score 15979.0
# Update Iter 34 Factor 0 Score 15976.8
# Update Iter 34 Factor 1 Score 15975.4
# Update Iter 34 Factor 2 Score 15975.2
# Update Iter 35 Factor 0 Score 15973.0
# Update Iter 35 Factor 1 Score 15971.6
# Update Iter 35 Factor 2 Score 15971.5
# Update Iter 36 Factor 0 Score 15969.3
# Update Iter 36 Factor 1 Score 15968.0
# Update Iter 36 Factor 2 Score 15967.8
# Update Iter 37 Factor 0 Score 15965.6
# Update Iter 37 Factor 1 Score 15964.3
# Update Iter 37 Factor 2 Score 15964.1
# Update Iter 38 Factor 0 Score 15962.0
# Update Iter 38 Factor 1 Score 15960.6
# Update Iter 38 Factor 2 Score 15960.5
# Update Iter 39 Factor 0 Score 15958.3
# Update Iter 39 Factor 1 Score 15957.0
# Update Iter 39 Factor 2 Score 15956.8
# Update Iter 40 Factor 0 Score 15954.7
# Update Iter 40 Factor 1 Score 15953.4
# Update Iter 40 Factor 2 Score 15953.2
# Update Iter 41 Factor 0 Score 15951.1
# Update Iter 41 Factor 1 Score 15949.8
# Update Iter 41 Factor 2 Score 15949.7
# Update Iter 42 Factor 0 Score 15947.6
# Update Iter 42 Factor 1 Score 15946.2
# Update Iter 42 Factor 2 Score 15946.1
# Update Iter 43 Factor 0 Score 15944.0
# Update Iter 43 Factor 1 Score 15942.7
# Update Iter 43 Factor 2 Score 15942.5
# Update Iter 44 Factor 0 Score 15940.5
# Update Iter 44 Factor 1 Score 15939.2
# Update Iter 44 Factor 2 Score 15939.0
# Update Iter 45 Factor 0 Score 15937.0
# Update Iter 45 Factor 1 Score 15935.7
# Update Iter 45 Factor 2 Score 15935.5
# Update Iter 46 Factor 0 Score 15933.5
# Update Iter 46 Factor 1 Score 15932.2
# Update Iter 46 Factor 2 Score 15932.0
# Update Iter 47 Factor 0 Score 15930.0
# Update Iter 47 Factor 1 Score 15928.7
# Update Iter 47 Factor 2 Score 15928.6
# Update Iter 48 Factor 0 Score 15926.5
# Update Iter 48 Factor 1 Score 15925.3
# Update Iter 48 Factor 2 Score 15925.1
# Update Iter 49 Factor 0 Score 15923.1
# Update Iter 49 Factor 1 Score 15921.8
# Update Iter 49 Factor 2 Score 15921.7
# Update Iter 50 Factor 0 Score 15919.7
# Update Iter 50 Factor 1 Score 15918.4
# Update Iter 50 Factor 2 Score 15918.3
# Update Iter 51 Factor 0 Score 15916.3
# Update Iter 51 Factor 1 Score 15915.1
# Update Iter 51 Factor 2 Score 15914.9
# Update Iter 52 Factor 0 Score 15912.9
# Update Iter 52 Factor 1 Score 15911.7
# Update Iter 52 Factor 2 Score 15911.6
# Update Iter 53 Factor 0 Score 15909.6
# Update Iter 53 Factor 1 Score 15908.3
# Update Iter 53 Factor 2 Score 15908.2
# Update Iter 54 Factor 0 Score 15906.3
# Update Iter 54 Factor 1 Score 15905.0
# Update Iter 54 Factor 2 Score 15904.9
# Update Iter 55 Factor 0 Score 15902.9
# Update Iter 55 Factor 1 Score 15901.7
# Update Iter 55 Factor 2 Score 15901.6
# Update Iter 56 Factor 0 Score 15899.7
# Update Iter 56 Factor 1 Score 15898.4
# Update Iter 56 Factor 2 Score 15898.3
# Update Iter 57 Factor 0 Score 15896.4
# Update Iter 57 Factor 1 Score 15895.2
# Update Iter 57 Factor 2 Score 15895.0
# Update Iter 58 Factor 0 Score 15893.1
# Update Iter 58 Factor 1 Score 15891.9
# Update Iter 58 Factor 2 Score 15891.8
# Update Iter 59 Factor 0 Score 15889.9
# Update Iter 59 Factor 1 Score 15888.7
# Update Iter 59 Factor 2 Score 15888.5
# Update Iter 60 Factor 0 Score 15886.7
# Update Iter 60 Factor 1 Score 15885.5
# Update Iter 60 Factor 2 Score 15885.3
# Update Iter 61 Factor 0 Score 15883.5
# Update Iter 61 Factor 1 Score 15882.3
# Update Iter 61 Factor 2 Score 15882.1
# Update Iter 62 Factor 0 Score 15880.3
# Update Iter 62 Factor 1 Score 15879.1
# Update Iter 62 Factor 2 Score 15879.0
# Update Iter 63 Factor 0 Score 15877.1
# Update Iter 63 Factor 1 Score 15875.9
# Update Iter 63 Factor 2 Score 15875.8
# Update Iter 64 Factor 0 Score 15873.9
# Update Iter 64 Factor 1 Score 15872.8
# Update Iter 64 Factor 2 Score 15872.6
# Update Iter 65 Factor 0 Score 15870.8
# Update Iter 65 Factor 1 Score 15869.6
# Update Iter 65 Factor 2 Score 15869.5
# Update Iter 66 Factor 0 Score 15867.7
# Update Iter 66 Factor 1 Score 15866.5
# Update Iter 66 Factor 2 Score 15866.4
# Update Iter 67 Factor 0 Score 15864.6
# Update Iter 67 Factor 1 Score 15863.4
# Update Iter 67 Factor 2 Score 15863.3
# Update Iter 68 Factor 0 Score 15861.5
# Update Iter 68 Factor 1 Score 15860.4
# Update Iter 68 Factor 2 Score 15860.2
# Update Iter 69 Factor 0 Score 15858.4
# Update Iter 69 Factor 1 Score 15857.3
# Update Iter 69 Factor 2 Score 15857.2
# Update Iter 70 Factor 0 Score 15855.4
# Update Iter 70 Factor 1 Score 15854.3
# Update Iter 70 Factor 2 Score 15854.1
# Update Iter 71 Factor 0 Score 15852.4
# Update Iter 71 Factor 1 Score 15851.2
# Update Iter 71 Factor 2 Score 15851.1
# Update Iter 72 Factor 0 Score 15849.3
# Update Iter 72 Factor 1 Score 15848.2
# Update Iter 72 Factor 2 Score 15848.1
# Update Iter 73 Factor 0 Score 15846.3
# Update Iter 73 Factor 1 Score 15845.2
# Update Iter 73 Factor 2 Score 15845.1
# Update Iter 74 Factor 0 Score 15843.3
# Update Iter 74 Factor 1 Score 15842.2
# Update Iter 74 Factor 2 Score 15842.1
# Update Iter 75 Factor 0 Score 15840.4
# Update Iter 75 Factor 1 Score 15839.3
# Update Iter 75 Factor 2 Score 15839.2
# Update Iter 76 Factor 0 Score 15837.4
# Update Iter 76 Factor 1 Score 15836.3
# Update Iter 76 Factor 2 Score 15836.2
# Update Iter 77 Factor 0 Score 15834.5
# Update Iter 77 Factor 1 Score 15833.4
# Update Iter 77 Factor 2 Score 15833.3
# Update Iter 78 Factor 0 Score 15831.6
# Update Iter 78 Factor 1 Score 15830.5
# Update Iter 78 Factor 2 Score 15830.4
# Update Iter 79 Factor 0 Score 15828.6
# Update Iter 79 Factor 1 Score 15827.6
# Update Iter 79 Factor 2 Score 15827.5
# Update Iter 80 Factor 0 Score 15825.8
# Update Iter 80 Factor 1 Score 15824.7
# Update Iter 80 Factor 2 Score 15824.6
# Update Iter 81 Factor 0 Score 15822.9
# Update Iter 81 Factor 1 Score 15821.8
# Update Iter 81 Factor 2 Score 15821.7
# Update Iter 82 Factor 0 Score 15820.0
# Update Iter 82 Factor 1 Score 15818.9
# Update Iter 82 Factor 2 Score 15818.8
# Update Iter 83 Factor 0 Score 15817.2
# Update Iter 83 Factor 1 Score 15816.1
# Update Iter 83 Factor 2 Score 15816.0
# Update Iter 84 Factor 0 Score 15814.3
# Update Iter 84 Factor 1 Score 15813.3
# Update Iter 84 Factor 2 Score 15813.2
# Update Iter 85 Factor 0 Score 15811.5
# Update Iter 85 Factor 1 Score 15810.5
# Update Iter 85 Factor 2 Score 15810.3
# Update Iter 86 Factor 0 Score 15808.7
# Update Iter 86 Factor 1 Score 15807.7
# Update Iter 86 Factor 2 Score 15807.5
# Update Iter 87 Factor 0 Score 15805.9
# Update Iter 87 Factor 1 Score 15804.9
# Update Iter 87 Factor 2 Score 15804.8
# Update Iter 88 Factor 0 Score 15803.1
# Update Iter 88 Factor 1 Score 15802.1
# Update Iter 88 Factor 2 Score 15802.0
# Update Iter 89 Factor 0 Score 15800.4
# Update Iter 89 Factor 1 Score 15799.3
# Update Iter 89 Factor 2 Score 15799.2
# Update Iter 90 Factor 0 Score 15797.6
# Update Iter 90 Factor 1 Score 15796.6
# Update Iter 90 Factor 2 Score 15796.5
# Update Iter 91 Factor 0 Score 15794.9
# Update Iter 91 Factor 1 Score 15793.9
# Update Iter 91 Factor 2 Score 15793.7
# Update Iter 92 Factor 0 Score 15792.2
# Update Iter 92 Factor 1 Score 15791.1
# Update Iter 92 Factor 2 Score 15791.0
# Update Iter 93 Factor 0 Score 15789.4
# Update Iter 93 Factor 1 Score 15788.4
# Update Iter 93 Factor 2 Score 15788.3
# Update Iter 94 Factor 0 Score 15786.7
# Update Iter 94 Factor 1 Score 15785.7
# Update Iter 94 Factor 2 Score 15785.6
# Update Iter 95 Factor 0 Score 15784.1
# Update Iter 95 Factor 1 Score 15783.1
# Update Iter 95 Factor 2 Score 15783.0
# Update Iter 96 Factor 0 Score 15781.4
# Update Iter 96 Factor 1 Score 15780.4
# Update Iter 96 Factor 2 Score 15780.3
# Update Iter 97 Factor 0 Score 15778.7
# Update Iter 97 Factor 1 Score 15777.7
# Update Iter 97 Factor 2 Score 15777.6
# Update Iter 98 Factor 0 Score 15776.1
# Update Iter 98 Factor 1 Score 15775.1
# Update Iter 98 Factor 2 Score 15775.0
# Update Iter 99 Factor 0 Score 15773.5
# Update Iter 99 Factor 1 Score 15772.5
# Update Iter 99 Factor 2 Score 15772.4
# Update Iter 100 Factor 0 Score 15770.8
# Update Iter 100 Factor 1 Score 15769.9
# Update Iter 100 Factor 2 Score 15769.8
# Update Iter 101 Factor 0 Score 15768.2
# Update Iter 101 Factor 1 Score 15767.3
# Update Iter 101 Factor 2 Score 15767.2
# Update Iter 102 Factor 0 Score 15765.6
# Update Iter 102 Factor 1 Score 15764.7
# Update Iter 102 Factor 2 Score 15764.6
# Update Iter 103 Factor 0 Score 15763.1
# Update Iter 103 Factor 1 Score 15762.1
# Update Iter 103 Factor 2 Score 15762.0
# Update Iter 104 Factor 0 Score 15760.5
# Update Iter 104 Factor 1 Score 15759.5
# Update Iter 104 Factor 2 Score 15759.4
# Update Iter 105 Factor 0 Score 15757.9
# Update Iter 105 Factor 1 Score 15757.0
# Update Iter 105 Factor 2 Score 15756.9
# Update Iter 106 Factor 0 Score 15755.4
# Update Iter 106 Factor 1 Score 15754.4
# Update Iter 106 Factor 2 Score 15754.3
# Update Iter 107 Factor 0 Score 15752.9
# Update Iter 107 Factor 1 Score 15751.9
# Update Iter 107 Factor 2 Score 15751.8
# Update Iter 108 Factor 0 Score 15750.3
# Update Iter 108 Factor 1 Score 15749.4
# Update Iter 108 Factor 2 Score 15749.3
# Update Iter 109 Factor 0 Score 15747.8
# Update Iter 109 Factor 1 Score 15746.9
# Update Iter 109 Factor 2 Score 15746.8
# Update Iter 110 Factor 0 Score 15745.3
# Update Iter 110 Factor 1 Score 15744.4
# Update Iter 110 Factor 2 Score 15744.3
# Update Iter 111 Factor 0 Score 15742.9
# Update Iter 111 Factor 1 Score 15741.9
# Update Iter 111 Factor 2 Score 15741.8
# Update Iter 112 Factor 0 Score 15740.4
# Update Iter 112 Factor 1 Score 15739.5
# Update Iter 112 Factor 2 Score 15739.4
# Update Iter 113 Factor 0 Score 15737.9
# Update Iter 113 Factor 1 Score 15737.0
# Update Iter 113 Factor 2 Score 15736.9
# Update Iter 114 Factor 0 Score 15735.5
# Update Iter 114 Factor 1 Score 15734.6
# Update Iter 114 Factor 2 Score 15734.5
# Update Iter 115 Factor 0 Score 15733.0
# Update Iter 115 Factor 1 Score 15732.1
# Update Iter 115 Factor 2 Score 15732.0
# Update Iter 116 Factor 0 Score 15730.6
# Update Iter 116 Factor 1 Score 15729.7
# Update Iter 116 Factor 2 Score 15729.6
# Update Iter 117 Factor 0 Score 15728.2
# Update Iter 117 Factor 1 Score 15727.3
# Update Iter 117 Factor 2 Score 15727.2
# Update Iter 118 Factor 0 Score 15725.8
# Update Iter 118 Factor 1 Score 15724.9
# Update Iter 118 Factor 2 Score 15724.8
# Update Iter 119 Factor 0 Score 15723.4
# Update Iter 119 Factor 1 Score 15722.5
# Update Iter 119 Factor 2 Score 15722.4
# Update Iter 120 Factor 0 Score 15721.0
# Update Iter 120 Factor 1 Score 15720.1
# Update Iter 120 Factor 2 Score 15720.0
# Update Iter 121 Factor 0 Score 15718.6
# Update Iter 121 Factor 1 Score 15717.8
# Update Iter 121 Factor 2 Score 15717.7
# Update Iter 122 Factor 0 Score 15716.3
# Update Iter 122 Factor 1 Score 15715.4
# Update Iter 122 Factor 2 Score 15715.3
# Update Iter 123 Factor 0 Score 15713.9
# Update Iter 123 Factor 1 Score 15713.1
# Update Iter 123 Factor 2 Score 15713.0
# Update Iter 124 Factor 0 Score 15711.6
# Update Iter 124 Factor 1 Score 15710.7
# Update Iter 124 Factor 2 Score 15710.6
# Update Iter 125 Factor 0 Score 15709.3
# Update Iter 125 Factor 1 Score 15708.4
# Update Iter 125 Factor 2 Score 15708.3
# Update Iter 126 Factor 0 Score 15707.0
# Update Iter 126 Factor 1 Score 15706.1
# Update Iter 126 Factor 2 Score 15706.0
# Update Iter 127 Factor 0 Score 15704.7
# Update Iter 127 Factor 1 Score 15703.8
# Update Iter 127 Factor 2 Score 15703.7
# Update Iter 128 Factor 0 Score 15702.4
# Update Iter 128 Factor 1 Score 15701.5
# Update Iter 128 Factor 2 Score 15701.4
# Update Iter 129 Factor 0 Score 15700.1
# Update Iter 129 Factor 1 Score 15699.2
# Update Iter 129 Factor 2 Score 15699.1
# Update Iter 130 Factor 0 Score 15697.8
# Update Iter 130 Factor 1 Score 15697.0
# Update Iter 130 Factor 2 Score 15696.9
# Update Iter 131 Factor 0 Score 15695.5
# Update Iter 131 Factor 1 Score 15694.7
# Update Iter 131 Factor 2 Score 15694.6
# Update Iter 132 Factor 0 Score 15693.3
# Update Iter 132 Factor 1 Score 15692.4
# Update Iter 132 Factor 2 Score 15692.4
# Update Iter 133 Factor 0 Score 15691.0
# Update Iter 133 Factor 1 Score 15690.2
# Update Iter 133 Factor 2 Score 15690.1
# Update Iter 134 Factor 0 Score 15688.8
# Update Iter 134 Factor 1 Score 15688.0
# Update Iter 134 Factor 2 Score 15687.9
# Update Iter 135 Factor 0 Score 15686.6
# Update Iter 135 Factor 1 Score 15685.7
# Update Iter 135 Factor 2 Score 15685.7
# Update Iter 136 Factor 0 Score 15684.4
# Update Iter 136 Factor 1 Score 15683.5
# Update Iter 136 Factor 2 Score 15683.4
# Update Iter 137 Factor 0 Score 15682.2
# Update Iter 137 Factor 1 Score 15681.3
# Update Iter 137 Factor 2 Score 15681.2
# Update Iter 138 Factor 0 Score 15680.0
# Update Iter 138 Factor 1 Score 15679.1
# Update Iter 138 Factor 2 Score 15679.0
# Update Iter 139 Factor 0 Score 15677.8
# Update Iter 139 Factor 1 Score 15677.0
# Update Iter 139 Factor 2 Score 15676.9
# Update Iter 140 Factor 0 Score 15675.6
# Update Iter 140 Factor 1 Score 15674.8
# Update Iter 140 Factor 2 Score 15674.7
# Update Iter 141 Factor 0 Score 15673.4
# Update Iter 141 Factor 1 Score 15672.6
# Update Iter 141 Factor 2 Score 15672.5
# Update Iter 142 Factor 0 Score 15671.3
# Update Iter 142 Factor 1 Score 15670.5
# Update Iter 142 Factor 2 Score 15670.4
# Update Iter 143 Factor 0 Score 15669.1
# Update Iter 143 Factor 1 Score 15668.3
# Update Iter 143 Factor 2 Score 15668.2
# Update Iter 144 Factor 0 Score 15667.0
# Update Iter 144 Factor 1 Score 15666.2
# Update Iter 144 Factor 2 Score 15666.1
# Update Iter 145 Factor 0 Score 15664.9
# Update Iter 145 Factor 1 Score 15664.1
# Update Iter 145 Factor 2 Score 15664.0
# Update Iter 146 Factor 0 Score 15662.7
# Update Iter 146 Factor 1 Score 15661.9
# Update Iter 146 Factor 2 Score 15661.9
# Update Iter 147 Factor 0 Score 15660.6
# Update Iter 147 Factor 1 Score 15659.8
# Update Iter 147 Factor 2 Score 15659.8
# Update Iter 148 Factor 0 Score 15658.5
# Update Iter 148 Factor 1 Score 15657.7
# Update Iter 148 Factor 2 Score 15657.7
# Update Iter 149 Factor 0 Score 15656.4
# Update Iter 149 Factor 1 Score 15655.7
# Update Iter 149 Factor 2 Score 15655.6
# Update Iter 150 Factor 0 Score 15654.3
# Update Iter 150 Factor 1 Score 15653.6
# Update Iter 150 Factor 2 Score 15653.5
# Update Iter 151 Factor 0 Score 15652.3
# Update Iter 151 Factor 1 Score 15651.5
# Update Iter 151 Factor 2 Score 15651.4
# Update Iter 152 Factor 0 Score 15650.2
# Update Iter 152 Factor 1 Score 15649.4
# Update Iter 152 Factor 2 Score 15649.4
# Update Iter 153 Factor 0 Score 15648.1
# Update Iter 153 Factor 1 Score 15647.4
# Update Iter 153 Factor 2 Score 15647.3
# Update Iter 154 Factor 0 Score 15646.1
# Update Iter 154 Factor 1 Score 15645.3
# Update Iter 154 Factor 2 Score 15645.2
# Update Iter 155 Factor 0 Score 15644.1
# Update Iter 155 Factor 1 Score 15643.3
# Update Iter 155 Factor 2 Score 15643.2
# Update Iter 156 Factor 0 Score 15642.0
# Update Iter 156 Factor 1 Score 15641.3
# Update Iter 156 Factor 2 Score 15641.2
# Update Iter 157 Factor 0 Score 15640.0
# Update Iter 157 Factor 1 Score 15639.2
# Update Iter 157 Factor 2 Score 15639.2
# Update Iter 158 Factor 0 Score 15638.0
# Update Iter 158 Factor 1 Score 15637.2
# Update Iter 158 Factor 2 Score 15637.1
# Update Iter 159 Factor 0 Score 15636.0
# Update Iter 159 Factor 1 Score 15635.2
# Update Iter 159 Factor 2 Score 15635.1
# Update Iter 160 Factor 0 Score 15634.0
# Update Iter 160 Factor 1 Score 15633.2
# Update Iter 160 Factor 2 Score 15633.2
# Update Iter 161 Factor 0 Score 15632.0
# Update Iter 161 Factor 1 Score 15631.2
# Update Iter 161 Factor 2 Score 15631.2
# Update Iter 162 Factor 0 Score 15630.0
# Update Iter 162 Factor 1 Score 15629.3
# Update Iter 162 Factor 2 Score 15629.2
# Update Iter 163 Factor 0 Score 15628.0
# Update Iter 163 Factor 1 Score 15627.3
# Update Iter 163 Factor 2 Score 15627.2
# Update Iter 164 Factor 0 Score 15626.1
# Update Iter 164 Factor 1 Score 15625.3
# Update Iter 164 Factor 2 Score 15625.2
# Update Iter 165 Factor 0 Score 15624.1
# Update Iter 165 Factor 1 Score 15623.4
# Update Iter 165 Factor 2 Score 15623.3
# Update Iter 166 Factor 0 Score 15622.2
# Update Iter 166 Factor 1 Score 15621.4
# Update Iter 166 Factor 2 Score 15621.3
# Update Iter 167 Factor 0 Score 15620.2
# Update Iter 167 Factor 1 Score 15619.5
# Update Iter 167 Factor 2 Score 15619.4
# Update Iter 168 Factor 0 Score 15618.3
# Update Iter 168 Factor 1 Score 15617.5
# Update Iter 168 Factor 2 Score 15617.5
# Update Iter 169 Factor 0 Score 15616.4
# Update Iter 169 Factor 1 Score 15615.6
# Update Iter 169 Factor 2 Score 15615.5
# Update Iter 170 Factor 0 Score 15614.4
# Update Iter 170 Factor 1 Score 15613.7
# Update Iter 170 Factor 2 Score 15613.6
# Update Iter 171 Factor 0 Score 15612.5
# Update Iter 171 Factor 1 Score 15611.8
# Update Iter 171 Factor 2 Score 15611.7
# Update Iter 172 Factor 0 Score 15610.6
# Update Iter 172 Factor 1 Score 15609.9
# Update Iter 172 Factor 2 Score 15609.8
# Update Iter 173 Factor 0 Score 15608.7
# Update Iter 173 Factor 1 Score 15608.0
# Update Iter 173 Factor 2 Score 15607.9
# Update Iter 174 Factor 0 Score 15606.8
# Update Iter 174 Factor 1 Score 15606.1
# Update Iter 174 Factor 2 Score 15606.1
# Update Iter 175 Factor 0 Score 15605.0
# Update Iter 175 Factor 1 Score 15604.2
# Update Iter 175 Factor 2 Score 15604.2
# Update Iter 176 Factor 0 Score 15603.1
# Update Iter 176 Factor 1 Score 15602.4
# Update Iter 176 Factor 2 Score 15602.3
# Update Iter 177 Factor 0 Score 15601.2
# Update Iter 177 Factor 1 Score 15600.5
# Update Iter 177 Factor 2 Score 15600.4
# Update Iter 178 Factor 0 Score 15599.4
# Update Iter 178 Factor 1 Score 15598.7
# Update Iter 178 Factor 2 Score 15598.6
# Update Iter 179 Factor 0 Score 15597.5
# Update Iter 179 Factor 1 Score 15596.8
# Update Iter 179 Factor 2 Score 15596.7
# Update Iter 180 Factor 0 Score 15595.7
# Update Iter 180 Factor 1 Score 15595.0
# Update Iter 180 Factor 2 Score 15594.9
# Update Iter 181 Factor 0 Score 15593.8
# Update Iter 181 Factor 1 Score 15593.1
# Update Iter 181 Factor 2 Score 15593.1
# Update Iter 182 Factor 0 Score 15592.0
# Update Iter 182 Factor 1 Score 15591.3
# Update Iter 182 Factor 2 Score 15591.2
# Update Iter 183 Factor 0 Score 15590.2
# Update Iter 183 Factor 1 Score 15589.5
# Update Iter 183 Factor 2 Score 15589.4
# Update Iter 184 Factor 0 Score 15588.4
# Update Iter 184 Factor 1 Score 15587.7
# Update Iter 184 Factor 2 Score 15587.6
# Update Iter 185 Factor 0 Score 15586.6
# Update Iter 185 Factor 1 Score 15585.9
# Update Iter 185 Factor 2 Score 15585.8
# Update Iter 186 Factor 0 Score 15584.8
# Update Iter 186 Factor 1 Score 15584.1
# Update Iter 186 Factor 2 Score 15584.0
# Update Iter 187 Factor 0 Score 15583.0
# Update Iter 187 Factor 1 Score 15582.3
# Update Iter 187 Factor 2 Score 15582.2
# Update Iter 188 Factor 0 Score 15581.2
# Update Iter 188 Factor 1 Score 15580.5
# Update Iter 188 Factor 2 Score 15580.4
# Update Iter 189 Factor 0 Score 15579.4
# Update Iter 189 Factor 1 Score 15578.7
# Update Iter 189 Factor 2 Score 15578.7
# Update Iter 190 Factor 0 Score 15577.6
# Update Iter 190 Factor 1 Score 15577.0
# Update Iter 190 Factor 2 Score 15576.9
# Update Iter 191 Factor 0 Score 15575.9
# Update Iter 191 Factor 1 Score 15575.2
# Update Iter 191 Factor 2 Score 15575.1
# Update Iter 192 Factor 0 Score 15574.1
# Update Iter 192 Factor 1 Score 15573.5
# Update Iter 192 Factor 2 Score 15573.4
# Update Iter 193 Factor 0 Score 15572.4
# Update Iter 193 Factor 1 Score 15571.7
# Update Iter 193 Factor 2 Score 15571.6
# Update Iter 194 Factor 0 Score 15570.6
# Update Iter 194 Factor 1 Score 15570.0
# Update Iter 194 Factor 2 Score 15569.9
# Update Iter 195 Factor 0 Score 15568.9
# Update Iter 195 Factor 1 Score 15568.2
# Update Iter 195 Factor 2 Score 15568.2
# Update Iter 196 Factor 0 Score 15567.2
# Update Iter 196 Factor 1 Score 15566.5
# Update Iter 196 Factor 2 Score 15566.4
# Update Iter 197 Factor 0 Score 15565.4
# Update Iter 197 Factor 1 Score 15564.8
# Update Iter 197 Factor 2 Score 15564.7
# Update Iter 198 Factor 0 Score 15563.7
# Update Iter 198 Factor 1 Score 15563.1
# Update Iter 198 Factor 2 Score 15563.0
# Update Iter 199 Factor 0 Score 15562.0
# Update Iter 199 Factor 1 Score 15561.4
# Update Iter 199 Factor 2 Score 15561.3
# Update Iter 200 Factor 0 Score 15560.3
# Update Iter 200 Factor 1 Score 15559.7
# Update Iter 200 Factor 2 Score 15559.6
# Update Iter 201 Factor 0 Score 15558.6
# Update Iter 201 Factor 1 Score 15558.0
# Update Iter 201 Factor 2 Score 15557.9
# Update Iter 202 Factor 0 Score 15556.9
# Update Iter 202 Factor 1 Score 15556.3
# Update Iter 202 Factor 2 Score 15556.2
# Update Iter 203 Factor 0 Score 15555.3
# Update Iter 203 Factor 1 Score 15554.6
# Update Iter 203 Factor 2 Score 15554.6
# Update Iter 204 Factor 0 Score 15553.6
# Update Iter 204 Factor 1 Score 15552.9
# Update Iter 204 Factor 2 Score 15552.9
# Update Iter 205 Factor 0 Score 15551.9
# Update Iter 205 Factor 1 Score 15551.3
# Update Iter 205 Factor 2 Score 15551.2
# Update Iter 206 Factor 0 Score 15550.2
# Update Iter 206 Factor 1 Score 15549.6
# Update Iter 206 Factor 2 Score 15549.5
# Update Iter 207 Factor 0 Score 15548.6
# Update Iter 207 Factor 1 Score 15548.0
# Update Iter 207 Factor 2 Score 15547.9
# Update Iter 208 Factor 0 Score 15546.9
# Update Iter 208 Factor 1 Score 15546.3
# Update Iter 208 Factor 2 Score 15546.3
# Update Iter 209 Factor 0 Score 15545.3
# Update Iter 209 Factor 1 Score 15544.7
# Update Iter 209 Factor 2 Score 15544.6
# Update Iter 210 Factor 0 Score 15543.7
# Update Iter 210 Factor 1 Score 15543.0
# Update Iter 210 Factor 2 Score 15543.0
# Update Iter 211 Factor 0 Score 15542.0
# Update Iter 211 Factor 1 Score 15541.4
# Update Iter 211 Factor 2 Score 15541.4
# Update Iter 212 Factor 0 Score 15540.4
# Update Iter 212 Factor 1 Score 15539.8
# Update Iter 212 Factor 2 Score 15539.7
# Update Iter 213 Factor 0 Score 15538.8
# Update Iter 213 Factor 1 Score 15538.2
# Update Iter 213 Factor 2 Score 15538.1
# Update Iter 214 Factor 0 Score 15537.2
# Update Iter 214 Factor 1 Score 15536.6
# Update Iter 214 Factor 2 Score 15536.5
# Update Iter 215 Factor 0 Score 15535.6
# Update Iter 215 Factor 1 Score 15535.0
# Update Iter 215 Factor 2 Score 15534.9
# Update Iter 216 Factor 0 Score 15534.0
# Update Iter 216 Factor 1 Score 15533.4
# Update Iter 216 Factor 2 Score 15533.3
# Update Iter 217 Factor 0 Score 15532.4
# Update Iter 217 Factor 1 Score 15531.8
# Update Iter 217 Factor 2 Score 15531.7
# Update Iter 218 Factor 0 Score 15530.8
# Update Iter 218 Factor 1 Score 15530.2
# Update Iter 218 Factor 2 Score 15530.1
# Update Iter 219 Factor 0 Score 15529.2
# Update Iter 219 Factor 1 Score 15528.6
# Update Iter 219 Factor 2 Score 15528.5
# Update Iter 220 Factor 0 Score 15527.6
# Update Iter 220 Factor 1 Score 15527.0
# Update Iter 220 Factor 2 Score 15527.0
# Update Iter 221 Factor 0 Score 15526.1
# Update Iter 221 Factor 1 Score 15525.5
# Update Iter 221 Factor 2 Score 15525.4
# Update Iter 222 Factor 0 Score 15524.5
# Update Iter 222 Factor 1 Score 15523.9
# Update Iter 222 Factor 2 Score 15523.8
# Update Iter 223 Factor 0 Score 15522.9
# Update Iter 223 Factor 1 Score 15522.4
# Update Iter 223 Factor 2 Score 15522.3
# Update Iter 224 Factor 0 Score 15521.4
# Update Iter 224 Factor 1 Score 15520.8
# Update Iter 224 Factor 2 Score 15520.7
# Update Iter 225 Factor 0 Score 15519.8
# Update Iter 225 Factor 1 Score 15519.3
# Update Iter 225 Factor 2 Score 15519.2
# Update Iter 226 Factor 0 Score 15518.3
# Update Iter 226 Factor 1 Score 15517.7
# Update Iter 226 Factor 2 Score 15517.7
# Update Iter 227 Factor 0 Score 15516.8
# Update Iter 227 Factor 1 Score 15516.2
# Update Iter 227 Factor 2 Score 15516.1
# Update Iter 228 Factor 0 Score 15515.2
# Update Iter 228 Factor 1 Score 15514.7
# Update Iter 228 Factor 2 Score 15514.6
# Update Iter 229 Factor 0 Score 15513.7
# Update Iter 229 Factor 1 Score 15513.1
# Update Iter 229 Factor 2 Score 15513.1
# Update Iter 230 Factor 0 Score 15512.2
# Update Iter 230 Factor 1 Score 15511.6
# Update Iter 230 Factor 2 Score 15511.6
# Update Iter 231 Factor 0 Score 15510.7
# Update Iter 231 Factor 1 Score 15510.1
# Update Iter 231 Factor 2 Score 15510.0
# Update Iter 232 Factor 0 Score 15509.2
# Update Iter 232 Factor 1 Score 15508.6
# Update Iter 232 Factor 2 Score 15508.5
# Update Iter 233 Factor 0 Score 15507.7
# Update Iter 233 Factor 1 Score 15507.1
# Update Iter 233 Factor 2 Score 15507.0
# Update Iter 234 Factor 0 Score 15506.2
# Update Iter 234 Factor 1 Score 15505.6
# Update Iter 234 Factor 2 Score 15505.5
# Update Iter 235 Factor 0 Score 15504.7
# Update Iter 235 Factor 1 Score 15504.1
# Update Iter 235 Factor 2 Score 15504.1
# Update Iter 236 Factor 0 Score 15503.2
# Update Iter 236 Factor 1 Score 15502.6
# Update Iter 236 Factor 2 Score 15502.6
# Update Iter 237 Factor 0 Score 15501.7
# Update Iter 237 Factor 1 Score 15501.2
# Update Iter 237 Factor 2 Score 15501.1
# Update Iter 238 Factor 0 Score 15500.2
# Update Iter 238 Factor 1 Score 15499.7
# Update Iter 238 Factor 2 Score 15499.6
# Update Iter 239 Factor 0 Score 15498.8
# Update Iter 239 Factor 1 Score 15498.2
# Update Iter 239 Factor 2 Score 15498.2
# Update Iter 240 Factor 0 Score 15497.3
# Update Iter 240 Factor 1 Score 15496.8
# Update Iter 240 Factor 2 Score 15496.7
# Update Iter 241 Factor 0 Score 15495.8
# Update Iter 241 Factor 1 Score 15495.3
# Update Iter 241 Factor 2 Score 15495.2
# Update Iter 242 Factor 0 Score 15494.4
# Update Iter 242 Factor 1 Score 15493.8
# Update Iter 242 Factor 2 Score 15493.8
# Update Iter 243 Factor 0 Score 15492.9
# Update Iter 243 Factor 1 Score 15492.4
# Update Iter 243 Factor 2 Score 15492.3
# Update Iter 244 Factor 0 Score 15491.5
# Update Iter 244 Factor 1 Score 15491.0
# Update Iter 244 Factor 2 Score 15490.9
# Update Iter 245 Factor 0 Score 15490.1
# Update Iter 245 Factor 1 Score 15489.5
# Update Iter 245 Factor 2 Score 15489.5
# Update Iter 246 Factor 0 Score 15488.6
# Update Iter 246 Factor 1 Score 15488.1
# Update Iter 246 Factor 2 Score 15488.0
# Update Iter 247 Factor 0 Score 15487.2
# Update Iter 247 Factor 1 Score 15486.7
# Update Iter 247 Factor 2 Score 15486.6
# Update Iter 248 Factor 0 Score 15485.8
# Update Iter 248 Factor 1 Score 15485.2
# Update Iter 248 Factor 2 Score 15485.2
# Update Iter 249 Factor 0 Score 15484.4
# Update Iter 249 Factor 1 Score 15483.8
# Update Iter 249 Factor 2 Score 15483.8
# Update Iter 250 Factor 0 Score 15482.9
# Update Iter 250 Factor 1 Score 15482.4
# Update Iter 250 Factor 2 Score 15482.4
# Update Iter 251 Factor 0 Score 15481.5
# Update Iter 251 Factor 1 Score 15481.0
# Update Iter 251 Factor 2 Score 15480.9
# Update Iter 252 Factor 0 Score 15480.1
# Update Iter 252 Factor 1 Score 15479.6
# Update Iter 252 Factor 2 Score 15479.5
# Update Iter 253 Factor 0 Score 15478.7
# Update Iter 253 Factor 1 Score 15478.2
# Update Iter 253 Factor 2 Score 15478.2
# Update Iter 254 Factor 0 Score 15477.3
# Update Iter 254 Factor 1 Score 15476.8
# Update Iter 254 Factor 2 Score 15476.8
# Update Iter 255 Factor 0 Score 15476.0
# Update Iter 255 Factor 1 Score 15475.4
# Update Iter 255 Factor 2 Score 15475.4
# Update Iter 256 Factor 0 Score 15474.6
# Update Iter 256 Factor 1 Score 15474.0
# Update Iter 256 Factor 2 Score 15474.0
# Update Iter 257 Factor 0 Score 15473.2
# Update Iter 257 Factor 1 Score 15472.7
# Update Iter 257 Factor 2 Score 15472.6
# Update Iter 258 Factor 0 Score 15471.8
# Update Iter 258 Factor 1 Score 15471.3
# Update Iter 258 Factor 2 Score 15471.2
# Update Iter 259 Factor 0 Score 15470.4
# Update Iter 259 Factor 1 Score 15469.9
# Update Iter 259 Factor 2 Score 15469.9
# Update Iter 260 Factor 0 Score 15469.1
# Update Iter 260 Factor 1 Score 15468.6
# Update Iter 260 Factor 2 Score 15468.5
# Update Iter 261 Factor 0 Score 15467.7
# Update Iter 261 Factor 1 Score 15467.2
# Update Iter 261 Factor 2 Score 15467.2
# Update Iter 262 Factor 0 Score 15466.4
# Update Iter 262 Factor 1 Score 15465.9
# Update Iter 262 Factor 2 Score 15465.8
# Update Iter 263 Factor 0 Score 15465.0
# Update Iter 263 Factor 1 Score 15464.5
# Update Iter 263 Factor 2 Score 15464.5
# Update Iter 264 Factor 0 Score 15463.7
# Update Iter 264 Factor 1 Score 15463.2
# Update Iter 264 Factor 2 Score 15463.1
# Update Iter 265 Factor 0 Score 15462.3
# Update Iter 265 Factor 1 Score 15461.8
# Update Iter 265 Factor 2 Score 15461.8
# Update Iter 266 Factor 0 Score 15461.0
# Update Iter 266 Factor 1 Score 15460.5
# Update Iter 266 Factor 2 Score 15460.4
# Update Iter 267 Factor 0 Score 15459.7
# Update Iter 267 Factor 1 Score 15459.2
# Update Iter 267 Factor 2 Score 15459.1
# Update Iter 268 Factor 0 Score 15458.3
# Update Iter 268 Factor 1 Score 15457.9
# Update Iter 268 Factor 2 Score 15457.8
# Update Iter 269 Factor 0 Score 15457.0
# Update Iter 269 Factor 1 Score 15456.5
# Update Iter 269 Factor 2 Score 15456.5
# Update Iter 270 Factor 0 Score 15455.7
# Update Iter 270 Factor 1 Score 15455.2
# Update Iter 270 Factor 2 Score 15455.2
# Update Iter 271 Factor 0 Score 15454.4
# Update Iter 271 Factor 1 Score 15453.9
# Update Iter 271 Factor 2 Score 15453.8
# Update Iter 272 Factor 0 Score 15453.1
# Update Iter 272 Factor 1 Score 15452.6
# Update Iter 272 Factor 2 Score 15452.5
# Update Iter 273 Factor 0 Score 15451.8
# Update Iter 273 Factor 1 Score 15451.3
# Update Iter 273 Factor 2 Score 15451.2
# Update Iter 274 Factor 0 Score 15450.5
# Update Iter 274 Factor 1 Score 15450.0
# Update Iter 274 Factor 2 Score 15449.9
# Update Iter 275 Factor 0 Score 15449.2
# Update Iter 275 Factor 1 Score 15448.7
# Update Iter 275 Factor 2 Score 15448.7
# Update Iter 276 Factor 0 Score 15447.9
# Update Iter 276 Factor 1 Score 15447.4
# Update Iter 276 Factor 2 Score 15447.4
# Update Iter 277 Factor 0 Score 15446.6
# Update Iter 277 Factor 1 Score 15446.1
# Update Iter 277 Factor 2 Score 15446.1
# Update Iter 278 Factor 0 Score 15445.3
# Update Iter 278 Factor 1 Score 15444.9
# Update Iter 278 Factor 2 Score 15444.8
# Update Iter 279 Factor 0 Score 15444.1
# Update Iter 279 Factor 1 Score 15443.6
# Update Iter 279 Factor 2 Score 15443.5
# Update Iter 280 Factor 0 Score 15442.8
# Update Iter 280 Factor 1 Score 15442.3
# Update Iter 280 Factor 2 Score 15442.2
# Update Iter 281 Factor 0 Score 15441.5
# Update Iter 281 Factor 1 Score 15441.0
# Update Iter 281 Factor 2 Score 15441.0
# Update Iter 282 Factor 0 Score 15440.2
# Update Iter 282 Factor 1 Score 15439.8
# Update Iter 282 Factor 2 Score 15439.7
# Update Iter 283 Factor 0 Score 15439.0
# Update Iter 283 Factor 1 Score 15438.5
# Update Iter 283 Factor 2 Score 15438.5
# Update Iter 284 Factor 0 Score 15437.7
# Update Iter 284 Factor 1 Score 15437.3
# Update Iter 284 Factor 2 Score 15437.2
# Update Iter 285 Factor 0 Score 15436.5
# Update Iter 285 Factor 1 Score 15436.0
# Update Iter 285 Factor 2 Score 15436.0
# Update Iter 286 Factor 0 Score 15435.2
# Update Iter 286 Factor 1 Score 15434.8
# Update Iter 286 Factor 2 Score 15434.7
# Update Iter 287 Factor 0 Score 15434.0
# Update Iter 287 Factor 1 Score 15433.5
# Update Iter 287 Factor 2 Score 15433.5
# Update Iter 288 Factor 0 Score 15432.7
# Update Iter 288 Factor 1 Score 15432.3
# Update Iter 288 Factor 2 Score 15432.2
# Update Iter 289 Factor 0 Score 15431.5
# Update Iter 289 Factor 1 Score 15431.0
# Update Iter 289 Factor 2 Score 15431.0
# Update Iter 290 Factor 0 Score 15430.3
# Update Iter 290 Factor 1 Score 15429.8
# Update Iter 290 Factor 2 Score 15429.8
# Update Iter 291 Factor 0 Score 15429.1
# Update Iter 291 Factor 1 Score 15428.6
# Update Iter 291 Factor 2 Score 15428.5
# Update Iter 292 Factor 0 Score 15427.8
# Update Iter 292 Factor 1 Score 15427.4
# Update Iter 292 Factor 2 Score 15427.3
# Update Iter 293 Factor 0 Score 15426.6
# Update Iter 293 Factor 1 Score 15426.2
# Update Iter 293 Factor 2 Score 15426.1
# Update Iter 294 Factor 0 Score 15425.4
# Update Iter 294 Factor 1 Score 15424.9
# Update Iter 294 Factor 2 Score 15424.9
# Update Iter 295 Factor 0 Score 15424.2
# Update Iter 295 Factor 1 Score 15423.7
# Update Iter 295 Factor 2 Score 15423.7
# Update Iter 296 Factor 0 Score 15423.0
# Update Iter 296 Factor 1 Score 15422.5
# Update Iter 296 Factor 2 Score 15422.5
# Update Iter 297 Factor 0 Score 15421.8
# Update Iter 297 Factor 1 Score 15421.3
# Update Iter 297 Factor 2 Score 15421.3
# Update Iter 298 Factor 0 Score 15420.6
# Update Iter 298 Factor 1 Score 15420.1
# Update Iter 298 Factor 2 Score 15420.1
# Update Iter 299 Factor 0 Score 15419.4
# Update Iter 299 Factor 1 Score 15418.9
# Update Iter 299 Factor 2 Score 15418.9
# Update Iter 300 Factor 0 Score 15418.2
# Update Iter 300 Factor 1 Score 15417.7
# Update Iter 300 Factor 2 Score 15417.7
# Update Iter 301 Factor 0 Score 15417.0
# Update Iter 301 Factor 1 Score 15416.6
# Update Iter 301 Factor 2 Score 15416.5
# Update Iter 302 Factor 0 Score 15415.8
# Update Iter 302 Factor 1 Score 15415.4
# Update Iter 302 Factor 2 Score 15415.3
# Update Iter 303 Factor 0 Score 15414.6
# Update Iter 303 Factor 1 Score 15414.2
# Update Iter 303 Factor 2 Score 15414.1
# Update Iter 304 Factor 0 Score 15413.5
# Update Iter 304 Factor 1 Score 15413.0
# Update Iter 304 Factor 2 Score 15413.0
# Update Iter 305 Factor 0 Score 15412.3
# Update Iter 305 Factor 1 Score 15411.8
# Update Iter 305 Factor 2 Score 15411.8
# Update Iter 306 Factor 0 Score 15411.1
# Update Iter 306 Factor 1 Score 15410.7
# Update Iter 306 Factor 2 Score 15410.6
# Update Iter 307 Factor 0 Score 15409.9
# Update Iter 307 Factor 1 Score 15409.5
# Update Iter 307 Factor 2 Score 15409.5
# Update Iter 308 Factor 0 Score 15408.8
# Update Iter 308 Factor 1 Score 15408.4
# Update Iter 308 Factor 2 Score 15408.3
# Update Iter 309 Factor 0 Score 15407.6
# Update Iter 309 Factor 1 Score 15407.2
# Update Iter 309 Factor 2 Score 15407.1
# Update Iter 310 Factor 0 Score 15406.5
# Update Iter 310 Factor 1 Score 15406.0
# Update Iter 310 Factor 2 Score 15406.0
# Update Iter 311 Factor 0 Score 15405.3
# Update Iter 311 Factor 1 Score 15404.9
# Update Iter 311 Factor 2 Score 15404.8
# Update Iter 312 Factor 0 Score 15404.2
# Update Iter 312 Factor 1 Score 15403.7
# Update Iter 312 Factor 2 Score 15403.7
# Update Iter 313 Factor 0 Score 15403.0
# Update Iter 313 Factor 1 Score 15402.6
# Update Iter 313 Factor 2 Score 15402.6
# Update Iter 314 Factor 0 Score 15401.9
# Update Iter 314 Factor 1 Score 15401.5
# Update Iter 314 Factor 2 Score 15401.4
# Update Iter 315 Factor 0 Score 15400.8
# Update Iter 315 Factor 1 Score 15400.3
# Update Iter 315 Factor 2 Score 15400.3
# Update Iter 316 Factor 0 Score 15399.6
# Update Iter 316 Factor 1 Score 15399.2
# Update Iter 316 Factor 2 Score 15399.1
# Update Iter 317 Factor 0 Score 15398.5
# Update Iter 317 Factor 1 Score 15398.1
# Update Iter 317 Factor 2 Score 15398.0
# Update Iter 318 Factor 0 Score 15397.4
# Update Iter 318 Factor 1 Score 15396.9
# Update Iter 318 Factor 2 Score 15396.9
# Update Iter 319 Factor 0 Score 15396.3
# Update Iter 319 Factor 1 Score 15395.8
# Update Iter 319 Factor 2 Score 15395.8
# Update Iter 320 Factor 0 Score 15395.1
# Update Iter 320 Factor 1 Score 15394.7
# Update Iter 320 Factor 2 Score 15394.7
# Update Iter 321 Factor 0 Score 15394.0
# Update Iter 321 Factor 1 Score 15393.6
# Update Iter 321 Factor 2 Score 15393.6
# Update Iter 322 Factor 0 Score 15392.9
# Update Iter 322 Factor 1 Score 15392.5
# Update Iter 322 Factor 2 Score 15392.4
# Update Iter 323 Factor 0 Score 15391.8
# Update Iter 323 Factor 1 Score 15391.4
# Update Iter 323 Factor 2 Score 15391.3
# Update Iter 324 Factor 0 Score 15390.7
# Update Iter 324 Factor 1 Score 15390.3
# Update Iter 324 Factor 2 Score 15390.2
# Update Iter 325 Factor 0 Score 15389.6
# Update Iter 325 Factor 1 Score 15389.2
# Update Iter 325 Factor 2 Score 15389.1
# Update Iter 326 Factor 0 Score 15388.5
# Update Iter 326 Factor 1 Score 15388.1
# Update Iter 326 Factor 2 Score 15388.0
# Update Iter 327 Factor 0 Score 15387.4
# Update Iter 327 Factor 1 Score 15387.0
# Update Iter 327 Factor 2 Score 15386.9
# Update Iter 328 Factor 0 Score 15386.3
# Update Iter 328 Factor 1 Score 15385.9
# Update Iter 328 Factor 2 Score 15385.9
# Update Iter 329 Factor 0 Score 15385.2
# Update Iter 329 Factor 1 Score 15384.8
# Update Iter 329 Factor 2 Score 15384.8
# Update Iter 330 Factor 0 Score 15384.1
# Update Iter 330 Factor 1 Score 15383.7
# Update Iter 330 Factor 2 Score 15383.7
# Update Iter 331 Factor 0 Score 15383.1
# Update Iter 331 Factor 1 Score 15382.6
# Update Iter 331 Factor 2 Score 15382.6
# Update Iter 332 Factor 0 Score 15382.0
# Update Iter 332 Factor 1 Score 15381.6
# Update Iter 332 Factor 2 Score 15381.5
# Update Iter 333 Factor 0 Score 15380.9
# Update Iter 333 Factor 1 Score 15380.5
# Update Iter 333 Factor 2 Score 15380.5
# Update Iter 334 Factor 0 Score 15379.8
# Update Iter 334 Factor 1 Score 15379.4
# Update Iter 334 Factor 2 Score 15379.4
# Update Iter 335 Factor 0 Score 15378.8
# Update Iter 335 Factor 1 Score 15378.4
# Update Iter 335 Factor 2 Score 15378.3
# Update Iter 336 Factor 0 Score 15377.7
# Update Iter 336 Factor 1 Score 15377.3
# Update Iter 336 Factor 2 Score 15377.2
# Update Iter 337 Factor 0 Score 15376.6
# Update Iter 337 Factor 1 Score 15376.2
# Update Iter 337 Factor 2 Score 15376.2
# Update Iter 338 Factor 0 Score 15375.6
# Update Iter 338 Factor 1 Score 15375.2
# Update Iter 338 Factor 2 Score 15375.1
# Update Iter 339 Factor 0 Score 15374.5
# Update Iter 339 Factor 1 Score 15374.1
# Update Iter 339 Factor 2 Score 15374.1
# Update Iter 340 Factor 0 Score 15373.5
# Update Iter 340 Factor 1 Score 15373.1
# Update Iter 340 Factor 2 Score 15373.0
# Update Iter 341 Factor 0 Score 15372.4
# Update Iter 341 Factor 1 Score 15372.0
# Update Iter 341 Factor 2 Score 15372.0
# Update Iter 342 Factor 0 Score 15371.4
# Update Iter 342 Factor 1 Score 15371.0
# Update Iter 342 Factor 2 Score 15370.9
# Update Iter 343 Factor 0 Score 15370.3
# Update Iter 343 Factor 1 Score 15369.9
# Update Iter 343 Factor 2 Score 15369.9
# Update Iter 344 Factor 0 Score 15369.3
# Update Iter 344 Factor 1 Score 15368.9
# Update Iter 344 Factor 2 Score 15368.9
# Update Iter 345 Factor 0 Score 15368.3
# Update Iter 345 Factor 1 Score 15367.9
# Update Iter 345 Factor 2 Score 15367.8
# Update Iter 346 Factor 0 Score 15367.2
# Update Iter 346 Factor 1 Score 15366.8
# Update Iter 346 Factor 2 Score 15366.8
# Update Iter 347 Factor 0 Score 15366.2
# Update Iter 347 Factor 1 Score 15365.8
# Update Iter 347 Factor 2 Score 15365.8
# Update Iter 348 Factor 0 Score 15365.2
# Update Iter 348 Factor 1 Score 15364.8
# Update Iter 348 Factor 2 Score 15364.7
# Update Iter 349 Factor 0 Score 15364.1
# Update Iter 349 Factor 1 Score 15363.7
# Update Iter 349 Factor 2 Score 15363.7
# Update Iter 350 Factor 0 Score 15363.1
# Update Iter 350 Factor 1 Score 15362.7
# Update Iter 350 Factor 2 Score 15362.7
# Update Iter 351 Factor 0 Score 15362.1
# Update Iter 351 Factor 1 Score 15361.7
# Update Iter 351 Factor 2 Score 15361.7
# Update Iter 352 Factor 0 Score 15361.1
# Update Iter 352 Factor 1 Score 15360.7
# Update Iter 352 Factor 2 Score 15360.6
# Update Iter 353 Factor 0 Score 15360.1
# Update Iter 353 Factor 1 Score 15359.7
# Update Iter 353 Factor 2 Score 15359.6
# Update Iter 354 Factor 0 Score 15359.1
# Update Iter 354 Factor 1 Score 15358.7
# Update Iter 354 Factor 2 Score 15358.6
# Update Iter 355 Factor 0 Score 15358.0
# Update Iter 355 Factor 1 Score 15357.7
# Update Iter 355 Factor 2 Score 15357.6
# Update Iter 356 Factor 0 Score 15357.0
# Update Iter 356 Factor 1 Score 15356.7
# Update Iter 356 Factor 2 Score 15356.6
# Update Iter 357 Factor 0 Score 15356.0
# Update Iter 357 Factor 1 Score 15355.7
# Update Iter 357 Factor 2 Score 15355.6
# Update Iter 358 Factor 0 Score 15355.0
# Update Iter 358 Factor 1 Score 15354.7
# Update Iter 358 Factor 2 Score 15354.6
# Update Iter 359 Factor 0 Score 15354.0
# Update Iter 359 Factor 1 Score 15353.7
# Update Iter 359 Factor 2 Score 15353.6
# Update Iter 360 Factor 0 Score 15353.0
# Update Iter 360 Factor 1 Score 15352.7
# Update Iter 360 Factor 2 Score 15352.6
# Update Iter 361 Factor 0 Score 15352.0
# Update Iter 361 Factor 1 Score 15351.7
# Update Iter 361 Factor 2 Score 15351.6
# Update Iter 362 Factor 0 Score 15351.1
# Update Iter 362 Factor 1 Score 15350.7
# Update Iter 362 Factor 2 Score 15350.6
# Update Iter 363 Factor 0 Score 15350.1
# Update Iter 363 Factor 1 Score 15349.7
# Update Iter 363 Factor 2 Score 15349.7
# Update Iter 364 Factor 0 Score 15349.1
# Update Iter 364 Factor 1 Score 15348.7
# Update Iter 364 Factor 2 Score 15348.7
# Update Iter 365 Factor 0 Score 15348.1
# Update Iter 365 Factor 1 Score 15347.7
# Update Iter 365 Factor 2 Score 15347.7
# Update Iter 366 Factor 0 Score 15347.1
# Update Iter 366 Factor 1 Score 15346.8
# Update Iter 366 Factor 2 Score 15346.7
# Update Iter 367 Factor 0 Score 15346.2
# Update Iter 367 Factor 1 Score 15345.8
# Update Iter 367 Factor 2 Score 15345.7
# Update Iter 368 Factor 0 Score 15345.2
# Update Iter 368 Factor 1 Score 15344.8
# Update Iter 368 Factor 2 Score 15344.8
# Update Iter 369 Factor 0 Score 15344.2
# Update Iter 369 Factor 1 Score 15343.8
# Update Iter 369 Factor 2 Score 15343.8
# Update Iter 370 Factor 0 Score 15343.2
# Update Iter 370 Factor 1 Score 15342.9
# Update Iter 370 Factor 2 Score 15342.8
# Update Iter 371 Factor 0 Score 15342.3
# Update Iter 371 Factor 1 Score 15341.9
# Update Iter 371 Factor 2 Score 15341.9
# Update Iter 372 Factor 0 Score 15341.3
# Update Iter 372 Factor 1 Score 15340.9
# Update Iter 372 Factor 2 Score 15340.9
# Update Iter 373 Factor 0 Score 15340.3
# Update Iter 373 Factor 1 Score 15340.0
# Update Iter 373 Factor 2 Score 15339.9
# Update Iter 374 Factor 0 Score 15339.4
# Update Iter 374 Factor 1 Score 15339.0
# Update Iter 374 Factor 2 Score 15339.0
# Update Iter 375 Factor 0 Score 15338.4
# Update Iter 375 Factor 1 Score 15338.1
# Update Iter 375 Factor 2 Score 15338.0
# Update Iter 376 Factor 0 Score 15337.5
# Update Iter 376 Factor 1 Score 15337.1
# Update Iter 376 Factor 2 Score 15337.1
# Update Iter 377 Factor 0 Score 15336.5
# Update Iter 377 Factor 1 Score 15336.2
# Update Iter 377 Factor 2 Score 15336.1
# Update Iter 378 Factor 0 Score 15335.6
# Update Iter 378 Factor 1 Score 15335.2
# Update Iter 378 Factor 2 Score 15335.2
# Update Iter 379 Factor 0 Score 15334.6
# Update Iter 379 Factor 1 Score 15334.3
# Update Iter 379 Factor 2 Score 15334.2
# Update Iter 380 Factor 0 Score 15333.7
# Update Iter 380 Factor 1 Score 15333.3
# Update Iter 380 Factor 2 Score 15333.3
# Update Iter 381 Factor 0 Score 15332.7
# Update Iter 381 Factor 1 Score 15332.4
# Update Iter 381 Factor 2 Score 15332.3
# Update Iter 382 Factor 0 Score 15331.8
# Update Iter 382 Factor 1 Score 15331.5
# Update Iter 382 Factor 2 Score 15331.4
# Update Iter 383 Factor 0 Score 15330.9
# Update Iter 383 Factor 1 Score 15330.5
# Update Iter 383 Factor 2 Score 15330.5
# Update Iter 384 Factor 0 Score 15329.9
# Update Iter 384 Factor 1 Score 15329.6
# Update Iter 384 Factor 2 Score 15329.5
# Update Iter 385 Factor 0 Score 15329.0
# Update Iter 385 Factor 1 Score 15328.7
# Update Iter 385 Factor 2 Score 15328.6
# Update Iter 386 Factor 0 Score 15328.1
# Update Iter 386 Factor 1 Score 15327.7
# Update Iter 386 Factor 2 Score 15327.7
# Update Iter 387 Factor 0 Score 15327.2
# Update Iter 387 Factor 1 Score 15326.8
# Update Iter 387 Factor 2 Score 15326.8
# Update Iter 388 Factor 0 Score 15326.2
# Update Iter 388 Factor 1 Score 15325.9
# Update Iter 388 Factor 2 Score 15325.8
# Update Iter 389 Factor 0 Score 15325.3
# Update Iter 389 Factor 1 Score 15325.0
# Update Iter 389 Factor 2 Score 15324.9
# Update Iter 390 Factor 0 Score 15324.4
# Update Iter 390 Factor 1 Score 15324.0
# Update Iter 390 Factor 2 Score 15324.0
# Update Iter 391 Factor 0 Score 15323.5
# Update Iter 391 Factor 1 Score 15323.1
# Update Iter 391 Factor 2 Score 15323.1
# Update Iter 392 Factor 0 Score 15322.6
# Update Iter 392 Factor 1 Score 15322.2
# Update Iter 392 Factor 2 Score 15322.2
# Update Iter 393 Factor 0 Score 15321.6
# Update Iter 393 Factor 1 Score 15321.3
# Update Iter 393 Factor 2 Score 15321.3
# Update Iter 394 Factor 0 Score 15320.7
# Update Iter 394 Factor 1 Score 15320.4
# Update Iter 394 Factor 2 Score 15320.4
# Update Iter 395 Factor 0 Score 15319.8
# Update Iter 395 Factor 1 Score 15319.5
# Update Iter 395 Factor 2 Score 15319.4
# Update Iter 396 Factor 0 Score 15318.9
# Update Iter 396 Factor 1 Score 15318.6
# Update Iter 396 Factor 2 Score 15318.5
# Update Iter 397 Factor 0 Score 15318.0
# Update Iter 397 Factor 1 Score 15317.7
# Update Iter 397 Factor 2 Score 15317.6
# Update Iter 398 Factor 0 Score 15317.1
# Update Iter 398 Factor 1 Score 15316.8
# Update Iter 398 Factor 2 Score 15316.7
# Update Iter 399 Factor 0 Score 15316.2
# Update Iter 399 Factor 1 Score 15315.9
# Update Iter 399 Factor 2 Score 15315.8
# Update Iter 400 Factor 0 Score 15315.3
# Update Iter 400 Factor 1 Score 15315.0
# Update Iter 400 Factor 2 Score 15315.0
# Update Iter 401 Factor 0 Score 15314.4
# Update Iter 401 Factor 1 Score 15314.1
# Update Iter 401 Factor 2 Score 15314.1
# Update Iter 402 Factor 0 Score 15313.5
# Update Iter 402 Factor 1 Score 15313.2
# Update Iter 402 Factor 2 Score 15313.2
# Update Iter 403 Factor 0 Score 15312.7
# Update Iter 403 Factor 1 Score 15312.3
# Update Iter 403 Factor 2 Score 15312.3
# Update Iter 404 Factor 0 Score 15311.8
# Update Iter 404 Factor 1 Score 15311.4
# Update Iter 404 Factor 2 Score 15311.4
# Update Iter 405 Factor 0 Score 15310.9
# Update Iter 405 Factor 1 Score 15310.5
# Update Iter 405 Factor 2 Score 15310.5
# Update Iter 406 Factor 0 Score 15310.0
# Update Iter 406 Factor 1 Score 15309.7
# Update Iter 406 Factor 2 Score 15309.6
# Update Iter 407 Factor 0 Score 15309.1
# Update Iter 407 Factor 1 Score 15308.8
# Update Iter 407 Factor 2 Score 15308.8
# Update Iter 408 Factor 0 Score 15308.2
# Update Iter 408 Factor 1 Score 15307.9
# Update Iter 408 Factor 2 Score 15307.9
# Update Iter 409 Factor 0 Score 15307.4
# Update Iter 409 Factor 1 Score 15307.0
# Update Iter 409 Factor 2 Score 15307.0
# Update Iter 410 Factor 0 Score 15306.5
# Update Iter 410 Factor 1 Score 15306.2
# Update Iter 410 Factor 2 Score 15306.1
# Update Iter 411 Factor 0 Score 15305.6
# Update Iter 411 Factor 1 Score 15305.3
# Update Iter 411 Factor 2 Score 15305.3
# Update Iter 412 Factor 0 Score 15304.8
# Update Iter 412 Factor 1 Score 15304.4
# Update Iter 412 Factor 2 Score 15304.4
# ...
# Update Iter 863 Factor 1 Score 15049.7
# Update Iter 863 Factor 2 Score 15049.7
# Update Iter 864 Factor 0 Score 15049.5
# Update Iter 864 Factor 1 Score 15049.4
# Update Iter 864 Factor 2 Score 15049.3
# Update Iter 865 Factor 0 Score 15049.1
# Update Iter 865 Factor 1 Score 15049.0
# Update Iter 865 Factor 2 Score 15049.0
# Update Iter 866 Factor 0 Score 15048.8
# Update Iter 866 Factor 1 Score 15048.6
# Update Iter 866 Factor 2 Score 15048.6
# Update Iter 867 Factor 0 Score 15048.4
# Update Iter 867 Factor 1 Score 15048.3
# Update Iter 867 Factor 2 Score 15048.2
# Update Iter 868 Factor 0 Score 15048.0
# Update Iter 868 Factor 1 Score 15047.9
# Update Iter 868 Factor 2 Score 15047.9
# Update Iter 869 Factor 0 Score 15047.7
# Update Iter 869 Factor 1 Score 15047.5
# Update Iter 869 Factor 2 Score 15047.5
# Update Iter 870 Factor 0 Score 15047.3
# Update Iter 870 Factor 1 Score 15047.1
# Update Iter 870 Factor 2 Score 15047.1
# Update Iter 871 Factor 0 Score 15046.9
# Update Iter 871 Factor 1 Score 15046.8
# Update Iter 871 Factor 2 Score 15046.8
# Update Iter 872 Factor 0 Score 15046.6
# Update Iter 872 Factor 1 Score 15046.4
# Update Iter 872 Factor 2 Score 15046.4
# Update Iter 873 Factor 0 Score 15046.2
# Update Iter 873 Factor 1 Score 15046.0
# Update Iter 873 Factor 2 Score 15046.0
# Update Iter 874 Factor 0 Score 15045.8
# Update Iter 874 Factor 1 Score 15045.7
# Update Iter 874 Factor 2 Score 15045.7
# Update Iter 875 Factor 0 Score 15045.5
# Update Iter 875 Factor 1 Score 15045.3
# Update Iter 875 Factor 2 Score 15045.3
# Update Iter 876 Factor 0 Score 15045.1
# Update Iter 876 Factor 1 Score 15044.9
# Update Iter 876 Factor 2 Score 15044.9
# Update Iter 877 Factor 0 Score 15044.7
# Update Iter 877 Factor 1 Score 15044.6
# Update Iter 877 Factor 2 Score 15044.6
# Update Iter 878 Factor 0 Score 15044.4
# Update Iter 878 Factor 1 Score 15044.2
# Update Iter 878 Factor 2 Score 15044.2
# Update Iter 879 Factor 0 Score 15044.0
# Update Iter 879 Factor 1 Score 15043.9
# Update Iter 879 Factor 2 Score 15043.8
# Update Iter 880 Factor 0 Score 15043.6
# Update Iter 880 Factor 1 Score 15043.5
# Update Iter 880 Factor 2 Score 15043.5
# Update Iter 881 Factor 0 Score 15043.3
# Update Iter 881 Factor 1 Score 15043.1
# Update Iter 881 Factor 2 Score 15043.1
# Update Iter 882 Factor 0 Score 15042.9
# Update Iter 882 Factor 1 Score 15042.8
# Update Iter 882 Factor 2 Score 15042.8
# Update Iter 883 Factor 0 Score 15042.5
# Update Iter 883 Factor 1 Score 15042.4
# Update Iter 883 Factor 2 Score 15042.4
# Update Iter 884 Factor 0 Score 15042.2
# Update Iter 884 Factor 1 Score 15042.0
# Update Iter 884 Factor 2 Score 15042.0
# Update Iter 885 Factor 0 Score 15041.8
# Update Iter 885 Factor 1 Score 15041.7
# Update Iter 885 Factor 2 Score 15041.7
# Update Iter 886 Factor 0 Score 15041.5
# Update Iter 886 Factor 1 Score 15041.3
# Update Iter 886 Factor 2 Score 15041.3
# Update Iter 887 Factor 0 Score 15041.1
# Update Iter 887 Factor 1 Score 15041.0
# Update Iter 887 Factor 2 Score 15041.0
# Update Iter 888 Factor 0 Score 15040.7
# Update Iter 888 Factor 1 Score 15040.6
# Update Iter 888 Factor 2 Score 15040.6
# Update Iter 889 Factor 0 Score 15040.4
# Update Iter 889 Factor 1 Score 15040.2
# Update Iter 889 Factor 2 Score 15040.2
# Update Iter 890 Factor 0 Score 15040.0
# Update Iter 890 Factor 1 Score 15039.9
# Update Iter 890 Factor 2 Score 15039.9
# Update Iter 891 Factor 0 Score 15039.7
# Update Iter 891 Factor 1 Score 15039.5
# Update Iter 891 Factor 2 Score 15039.5
# Update Iter 892 Factor 0 Score 15039.3
# Update Iter 892 Factor 1 Score 15039.2
# Update Iter 892 Factor 2 Score 15039.2
# Update Iter 893 Factor 0 Score 15038.9
# Update Iter 893 Factor 1 Score 15038.8
# Update Iter 893 Factor 2 Score 15038.8
# Update Iter 894 Factor 0 Score 15038.6
# Update Iter 894 Factor 1 Score 15038.5
# Update Iter 894 Factor 2 Score 15038.4
# Update Iter 895 Factor 0 Score 15038.2
# Update Iter 895 Factor 1 Score 15038.1
# Update Iter 895 Factor 2 Score 15038.1
# Update Iter 896 Factor 0 Score 15037.9
# Update Iter 896 Factor 1 Score 15037.7
# Update Iter 896 Factor 2 Score 15037.7
# Update Iter 897 Factor 0 Score 15037.5
# Update Iter 897 Factor 1 Score 15037.4
# Update Iter 897 Factor 2 Score 15037.4
# Update Iter 898 Factor 0 Score 15037.2
# Update Iter 898 Factor 1 Score 15037.0
# Update Iter 898 Factor 2 Score 15037.0
# Update Iter 899 Factor 0 Score 15036.8
# Update Iter 899 Factor 1 Score 15036.7
# Update Iter 899 Factor 2 Score 15036.7
# Update Iter 900 Factor 0 Score 15036.5
# Update Iter 900 Factor 1 Score 15036.3
# Update Iter 900 Factor 2 Score 15036.3
# Update Iter 901 Factor 0 Score 15036.1
# Update Iter 901 Factor 1 Score 15036.0
# Update Iter 901 Factor 2 Score 15036.0
# Update Iter 902 Factor 0 Score 15035.7
# Update Iter 902 Factor 1 Score 15035.6
# Update Iter 902 Factor 2 Score 15035.6
# Update Iter 903 Factor 0 Score 15035.4
# Update Iter 903 Factor 1 Score 15035.3
# Update Iter 903 Factor 2 Score 15035.2
# Update Iter 904 Factor 0 Score 15035.0
# Update Iter 904 Factor 1 Score 15034.9
# Update Iter 904 Factor 2 Score 15034.9
# Update Iter 905 Factor 0 Score 15034.7
# Update Iter 905 Factor 1 Score 15034.5
# Update Iter 905 Factor 2 Score 15034.5
# Update Iter 906 Factor 0 Score 15034.3
# Update Iter 906 Factor 1 Score 15034.2
# Update Iter 906 Factor 2 Score 15034.2
# Update Iter 907 Factor 0 Score 15034.0
# Update Iter 907 Factor 1 Score 15033.8
# Update Iter 907 Factor 2 Score 15033.8
# Update Iter 908 Factor 0 Score 15033.6
# Update Iter 908 Factor 1 Score 15033.5
# Update Iter 908 Factor 2 Score 15033.5
# Update Iter 909 Factor 0 Score 15033.3
# Update Iter 909 Factor 1 Score 15033.1
# Update Iter 909 Factor 2 Score 15033.1
# Update Iter 910 Factor 0 Score 15032.9
# Update Iter 910 Factor 1 Score 15032.8
# Update Iter 910 Factor 2 Score 15032.8
# Update Iter 911 Factor 0 Score 15032.6
# Update Iter 911 Factor 1 Score 15032.4
# Update Iter 911 Factor 2 Score 15032.4
# Update Iter 912 Factor 0 Score 15032.2
# Update Iter 912 Factor 1 Score 15032.1
# Update Iter 912 Factor 2 Score 15032.1
# Update Iter 913 Factor 0 Score 15031.9
# Update Iter 913 Factor 1 Score 15031.7
# Update Iter 913 Factor 2 Score 15031.7
# Update Iter 914 Factor 0 Score 15031.5
# Update Iter 914 Factor 1 Score 15031.4
# Update Iter 914 Factor 2 Score 15031.4
# Update Iter 915 Factor 0 Score 15031.2
# Update Iter 915 Factor 1 Score 15031.0
# Update Iter 915 Factor 2 Score 15031.0
# Update Iter 916 Factor 0 Score 15030.8
# Update Iter 916 Factor 1 Score 15030.7
# Update Iter 916 Factor 2 Score 15030.7
# Update Iter 917 Factor 0 Score 15030.5
# Update Iter 917 Factor 1 Score 15030.3
# Update Iter 917 Factor 2 Score 15030.3
# Update Iter 918 Factor 0 Score 15030.1
# Update Iter 918 Factor 1 Score 15030.0
# Update Iter 918 Factor 2 Score 15030.0
# Update Iter 919 Factor 0 Score 15029.8
# Update Iter 919 Factor 1 Score 15029.7
# Update Iter 919 Factor 2 Score 15029.6
# Update Iter 920 Factor 0 Score 15029.4
# Update Iter 920 Factor 1 Score 15029.3
# Update Iter 920 Factor 2 Score 15029.3
# Update Iter 921 Factor 0 Score 15029.1
# Update Iter 921 Factor 1 Score 15029.0
# Update Iter 921 Factor 2 Score 15029.0
# Update Iter 922 Factor 0 Score 15028.8
# Update Iter 922 Factor 1 Score 15028.6
# Update Iter 922 Factor 2 Score 15028.6
# Update Iter 923 Factor 0 Score 15028.4
# Update Iter 923 Factor 1 Score 15028.3
# Update Iter 923 Factor 2 Score 15028.3
# Update Iter 924 Factor 0 Score 15028.1
# Update Iter 924 Factor 1 Score 15027.9
# Update Iter 924 Factor 2 Score 15027.9
# Update Iter 925 Factor 0 Score 15027.7
# Update Iter 925 Factor 1 Score 15027.6
# Update Iter 925 Factor 2 Score 15027.6
# Update Iter 926 Factor 0 Score 15027.4
# Update Iter 926 Factor 1 Score 15027.2
# Update Iter 926 Factor 2 Score 15027.2
# Update Iter 927 Factor 0 Score 15027.0
# Update Iter 927 Factor 1 Score 15026.9
# Update Iter 927 Factor 2 Score 15026.9
# Update Iter 928 Factor 0 Score 15026.7
# Update Iter 928 Factor 1 Score 15026.6
# Update Iter 928 Factor 2 Score 15026.5
# Update Iter 929 Factor 0 Score 15026.3
# Update Iter 929 Factor 1 Score 15026.2
# Update Iter 929 Factor 2 Score 15026.2
# Update Iter 930 Factor 0 Score 15026.0
# Update Iter 930 Factor 1 Score 15025.9
# Update Iter 930 Factor 2 Score 15025.9
# Update Iter 931 Factor 0 Score 15025.7
# Update Iter 931 Factor 1 Score 15025.5
# Update Iter 931 Factor 2 Score 15025.5
# Update Iter 932 Factor 0 Score 15025.3
# Update Iter 932 Factor 1 Score 15025.2
# Update Iter 932 Factor 2 Score 15025.2
# Update Iter 933 Factor 0 Score 15025.0
# Update Iter 933 Factor 1 Score 15024.9
# Update Iter 933 Factor 2 Score 15024.8
# Update Iter 934 Factor 0 Score 15024.6
# Update Iter 934 Factor 1 Score 15024.5
# Update Iter 934 Factor 2 Score 15024.5
# Update Iter 935 Factor 0 Score 15024.3
# Update Iter 935 Factor 1 Score 15024.2
# Update Iter 935 Factor 2 Score 15024.2
# Update Iter 936 Factor 0 Score 15024.0
# Update Iter 936 Factor 1 Score 15023.8
# Update Iter 936 Factor 2 Score 15023.8
# Update Iter 937 Factor 0 Score 15023.6
# Update Iter 937 Factor 1 Score 15023.5
# Update Iter 937 Factor 2 Score 15023.5
# Update Iter 938 Factor 0 Score 15023.3
# Update Iter 938 Factor 1 Score 15023.2
# Update Iter 938 Factor 2 Score 15023.2
# Update Iter 939 Factor 0 Score 15022.9
# Update Iter 939 Factor 1 Score 15022.8
# Update Iter 939 Factor 2 Score 15022.8
# Update Iter 940 Factor 0 Score 15022.6
# Update Iter 940 Factor 1 Score 15022.5
# Update Iter 940 Factor 2 Score 15022.5
# Update Iter 941 Factor 0 Score 15022.3
# Update Iter 941 Factor 1 Score 15022.1
# Update Iter 941 Factor 2 Score 15022.1
# Update Iter 942 Factor 0 Score 15021.9
# Update Iter 942 Factor 1 Score 15021.8
# Update Iter 942 Factor 2 Score 15021.8
# Update Iter 943 Factor 0 Score 15021.6
# Update Iter 943 Factor 1 Score 15021.5
# Update Iter 943 Factor 2 Score 15021.5
# Update Iter 944 Factor 0 Score 15021.3
# Update Iter 944 Factor 1 Score 15021.1
# Update Iter 944 Factor 2 Score 15021.1
# Update Iter 945 Factor 0 Score 15020.9
# Update Iter 945 Factor 1 Score 15020.8
# Update Iter 945 Factor 2 Score 15020.8
# Update Iter 946 Factor 0 Score 15020.6
# Update Iter 946 Factor 1 Score 15020.5
# Update Iter 946 Factor 2 Score 15020.5
# Update Iter 947 Factor 0 Score 15020.3
# Update Iter 947 Factor 1 Score 15020.1
# Update Iter 947 Factor 2 Score 15020.1
# Update Iter 948 Factor 0 Score 15019.9
# Update Iter 948 Factor 1 Score 15019.8
# Update Iter 948 Factor 2 Score 15019.8
# Update Iter 949 Factor 0 Score 15019.6
# Update Iter 949 Factor 1 Score 15019.5
# Update Iter 949 Factor 2 Score 15019.5
# Update Iter 950 Factor 0 Score 15019.3
# Update Iter 950 Factor 1 Score 15019.1
# Update Iter 950 Factor 2 Score 15019.1
# Update Iter 951 Factor 0 Score 15018.9
# Update Iter 951 Factor 1 Score 15018.8
# Update Iter 951 Factor 2 Score 15018.8
# Update Iter 952 Factor 0 Score 15018.6
# Update Iter 952 Factor 1 Score 15018.5
# Update Iter 952 Factor 2 Score 15018.5
# Update Iter 953 Factor 0 Score 15018.3
# Update Iter 953 Factor 1 Score 15018.1
# Update Iter 953 Factor 2 Score 15018.1
# Update Iter 954 Factor 0 Score 15017.9
# Update Iter 954 Factor 1 Score 15017.8
# Update Iter 954 Factor 2 Score 15017.8
# Update Iter 955 Factor 0 Score 15017.6
# Update Iter 955 Factor 1 Score 15017.5
# Update Iter 955 Factor 2 Score 15017.5
# Update Iter 956 Factor 0 Score 15017.3
# Update Iter 956 Factor 1 Score 15017.2
# Update Iter 956 Factor 2 Score 15017.1
# Update Iter 957 Factor 0 Score 15017.0
# Update Iter 957 Factor 1 Score 15016.8
# Update Iter 957 Factor 2 Score 15016.8
# Update Iter 958 Factor 0 Score 15016.6
# Update Iter 958 Factor 1 Score 15016.5
# Update Iter 958 Factor 2 Score 15016.5
# Update Iter 959 Factor 0 Score 15016.3
# Update Iter 959 Factor 1 Score 15016.2
# Update Iter 959 Factor 2 Score 15016.2
# Update Iter 960 Factor 0 Score 15016.0
# Update Iter 960 Factor 1 Score 15015.8
# Update Iter 960 Factor 2 Score 15015.8
# Update Iter 961 Factor 0 Score 15015.6
# Update Iter 961 Factor 1 Score 15015.5
# Update Iter 961 Factor 2 Score 15015.5
# Update Iter 962 Factor 0 Score 15015.3
# Update Iter 962 Factor 1 Score 15015.2
# Update Iter 962 Factor 2 Score 15015.2
# Update Iter 963 Factor 0 Score 15015.0
# Update Iter 963 Factor 1 Score 15014.9
# Update Iter 963 Factor 2 Score 15014.8
# Update Iter 964 Factor 0 Score 15014.7
# Update Iter 964 Factor 1 Score 15014.5
# Update Iter 964 Factor 2 Score 15014.5
# Update Iter 965 Factor 0 Score 15014.3
# Update Iter 965 Factor 1 Score 15014.2
# Update Iter 965 Factor 2 Score 15014.2
# Update Iter 966 Factor 0 Score 15014.0
# Update Iter 966 Factor 1 Score 15013.9
# Update Iter 966 Factor 2 Score 15013.9
# Update Iter 967 Factor 0 Score 15013.7
# Update Iter 967 Factor 1 Score 15013.6
# Update Iter 967 Factor 2 Score 15013.5
# Update Iter 968 Factor 0 Score 15013.4
# Update Iter 968 Factor 1 Score 15013.2
# Update Iter 968 Factor 2 Score 15013.2
# Update Iter 969 Factor 0 Score 15013.0
# Update Iter 969 Factor 1 Score 15012.9
# Update Iter 969 Factor 2 Score 15012.9
# Update Iter 970 Factor 0 Score 15012.7
# Update Iter 970 Factor 1 Score 15012.6
# Update Iter 970 Factor 2 Score 15012.6
# Update Iter 971 Factor 0 Score 15012.4
# Update Iter 971 Factor 1 Score 15012.3
# Update Iter 971 Factor 2 Score 15012.2
# Update Iter 972 Factor 0 Score 15012.1
# Update Iter 972 Factor 1 Score 15011.9
# Update Iter 972 Factor 2 Score 15011.9
# Update Iter 973 Factor 0 Score 15011.7
# Update Iter 973 Factor 1 Score 15011.6
# Update Iter 973 Factor 2 Score 15011.6
# Update Iter 974 Factor 0 Score 15011.4
# Update Iter 974 Factor 1 Score 15011.3
# Update Iter 974 Factor 2 Score 15011.3
# Update Iter 975 Factor 0 Score 15011.1
# Update Iter 975 Factor 1 Score 15011.0
# Update Iter 975 Factor 2 Score 15011.0
# Update Iter 976 Factor 0 Score 15010.8
# Update Iter 976 Factor 1 Score 15010.6
# Update Iter 976 Factor 2 Score 15010.6
# Update Iter 977 Factor 0 Score 15010.4
# Update Iter 977 Factor 1 Score 15010.3
# Update Iter 977 Factor 2 Score 15010.3
# Update Iter 978 Factor 0 Score 15010.1
# Update Iter 978 Factor 1 Score 15010.0
# Update Iter 978 Factor 2 Score 15010.0
# Update Iter 979 Factor 0 Score 15009.8
# Update Iter 979 Factor 1 Score 15009.7
# Update Iter 979 Factor 2 Score 15009.7
# Update Iter 980 Factor 0 Score 15009.5
# Update Iter 980 Factor 1 Score 15009.4
# Update Iter 980 Factor 2 Score 15009.4
# Update Iter 981 Factor 0 Score 15009.2
# Update Iter 981 Factor 1 Score 15009.0
# Update Iter 981 Factor 2 Score 15009.0
# Update Iter 982 Factor 0 Score 15008.8
# Update Iter 982 Factor 1 Score 15008.7
# Update Iter 982 Factor 2 Score 15008.7
# Update Iter 983 Factor 0 Score 15008.5
# Update Iter 983 Factor 1 Score 15008.4
# Update Iter 983 Factor 2 Score 15008.4
# Update Iter 984 Factor 0 Score 15008.2
# Update Iter 984 Factor 1 Score 15008.1
# Update Iter 984 Factor 2 Score 15008.1
# Update Iter 985 Factor 0 Score 15007.9
# Update Iter 985 Factor 1 Score 15007.8
# Update Iter 985 Factor 2 Score 15007.8
# Update Iter 986 Factor 0 Score 15007.6
# Update Iter 986 Factor 1 Score 15007.4
# Update Iter 986 Factor 2 Score 15007.4
# Update Iter 987 Factor 0 Score 15007.3
# Update Iter 987 Factor 1 Score 15007.1
# Update Iter 987 Factor 2 Score 15007.1
# Update Iter 988 Factor 0 Score 15006.9
# Update Iter 988 Factor 1 Score 15006.8
# Update Iter 988 Factor 2 Score 15006.8
# Update Iter 989 Factor 0 Score 15006.6
# Update Iter 989 Factor 1 Score 15006.5
# Update Iter 989 Factor 2 Score 15006.5
# Update Iter 990 Factor 0 Score 15006.3
# Update Iter 990 Factor 1 Score 15006.2
# Update Iter 990 Factor 2 Score 15006.2
# Update Iter 991 Factor 0 Score 15006.0
# Update Iter 991 Factor 1 Score 15005.9
# Update Iter 991 Factor 2 Score 15005.9
# Update Iter 992 Factor 0 Score 15005.7
# Update Iter 992 Factor 1 Score 15005.6
# Update Iter 992 Factor 2 Score 15005.5
# Update Iter 993 Factor 0 Score 15005.4
# Update Iter 993 Factor 1 Score 15005.2
# Update Iter 993 Factor 2 Score 15005.2
# Update Iter 994 Factor 0 Score 15005.0
# Update Iter 994 Factor 1 Score 15004.9
# Update Iter 994 Factor 2 Score 15004.9
# Update Iter 995 Factor 0 Score 15004.7
# Update Iter 995 Factor 1 Score 15004.6
# Update Iter 995 Factor 2 Score 15004.6
# Update Iter 996 Factor 0 Score 15004.4
# Update Iter 996 Factor 1 Score 15004.3
# Update Iter 996 Factor 2 Score 15004.3
# Update Iter 997 Factor 0 Score 15004.1
# Update Iter 997 Factor 1 Score 15004.0
# Update Iter 997 Factor 2 Score 15004.0
# Update Iter 998 Factor 0 Score 15003.8
# Update Iter 998 Factor 1 Score 15003.7
# Update Iter 998 Factor 2 Score 15003.7
# Update Iter 999 Factor 0 Score 15003.5
# Update Iter 999 Factor 1 Score 15003.4
# Update Iter 999 Factor 2 Score 15003.4

# %%
prediction = bnf.impute(indices_test)

# %%
# rmse(prediction, val_test) / float(prediction.shape[0])
print mean_squared_error(prediction * multiplier_test, val_test * multiplier_test) 
print mean_absolute_error(prediction * multiplier_test, val_test * multiplier_test)

#print ratings['Rating'].mean()
#print 5 / ratings['Rating'].mean()
# Out:
# 5.12925551358
# 0.767176846831

# %%
val_test * multiplier_test
# Out:
# array([ 4.,  2.,  5., ...,  5.,  3.,  3.])

# %%
prediction * multiplier_test
# Out:
# array([ 4.31813305,  4.14295961,  4.87178581, ...,  3.85228047,
#         3.17982888,  3.9550476 ])

# %%
np.sqrt(np.mean(((val_test - prediction) * multiplier_test)**2.0))
# Out:
# 2.2647859752256396

# %%
# !cat ml-1m/README
# Out:
# SUMMARY
# ================================================================================
#
# These files contain 1,000,209 anonymous ratings of approximately 3,900 movies
# made by 6,040 MovieLens users who joined MovieLens in 2000.
#
# USAGE LICENSE
# ================================================================================
#
# Neither the University of Minnesota nor any of the researchers
# involved can guarantee the correctness of the data, its suitability
# for any particular purpose, or the validity of results based on the
# use of the data set.  The data set may be used for any research
# purposes under the following conditions:
#
#      * The user may not state or imply any endorsement from the
#        University of Minnesota or the GroupLens Research Group.
#
#      * The user must acknowledge the use of the data set in
#        publications resulting from the use of the data set, and must
#        send us an electronic or paper copy of those publications.
#
#      * The user may not redistribute the data without separate
#        permission.
#
#      * The user may not use this information for any commercial or
#        revenue-bearing purposes without first obtaining permission
#        from a faculty member of the GroupLens Research Project at the
#        University of Minnesota.
#
# If you have any further questions or comments, please contact GroupLens
# <grouplens-info@cs.umn.edu>.
#
# ACKNOWLEDGEMENTS
# ================================================================================
#
# Thanks to Shyong Lam and Jon Herlocker for cleaning up and generating the data
# set.
#
# FURTHER INFORMATION ABOUT THE GROUPLENS RESEARCH PROJECT
# ================================================================================
#
# The GroupLens Research Project is a research group in the Department of
# Computer Science and Engineering at the University of Minnesota. Members of
# the GroupLens Research Project are involved in many research projects related
# to the fields of information filtering, collaborative filtering, and
# recommender systems. The project is lead by professors John Riedl and Joseph
# Konstan. The project began to explore automated collaborative filtering in
# 1992, but is most well known for its world wide trial of an automated
# collaborative filtering system for Usenet news in 1996. Since then the project
# has expanded its scope to research overall information filtering solutions,
# integrating in content-based methods as well as improving current collaborative
# filtering technology.
#
# Further information on the GroupLens Research project, including research
# publications, can be found at the following web site:
#
#         http://www.grouplens.org/
#
# GroupLens Research currently operates a movie recommender based on
# collaborative filtering:
#
#         http://www.movielens.org/
#
# RATINGS FILE DESCRIPTION
# ================================================================================
#
# All ratings are contained in the file "ratings.dat" and are in the
# following format:
#
# UserID::MovieID::Rating::Timestamp
#
# - UserIDs range between 1 and 6040
# - MovieIDs range between 1 and 3952
# - Ratings are made on a 5-star scale (whole-star ratings only)
# - Timestamp is represented in seconds since the epoch as returned by time(2)
# - Each user has at least 20 ratings
#
# USERS FILE DESCRIPTION
# ================================================================================
#
# User information is in the file "users.dat" and is in the following
# format:
#
# UserID::Gender::Age::Occupation::Zip-code
#
# All demographic information is provided voluntarily by the users and is
# not checked for accuracy.  Only users who have provided some demographic
# information are included in this data set.
#
# - Gender is denoted by a "M" for male and "F" for female
# - Age is chosen from the following ranges:
#
# 	*  1:  "Under 18"
# 	* 18:  "18-24"
# 	* 25:  "25-34"
# 	* 35:  "35-44"
# 	* 45:  "45-49"
# 	* 50:  "50-55"
# 	* 56:  "56+"
#
# - Occupation is chosen from the following choices:
#
# 	*  0:  "other" or not specified
# 	*  1:  "academic/educator"
# 	*  2:  "artist"
# 	*  3:  "clerical/admin"
# 	*  4:  "college/grad student"
# 	*  5:  "customer service"
# 	*  6:  "doctor/health care"
# 	*  7:  "executive/managerial"
# 	*  8:  "farmer"
# 	*  9:  "homemaker"
# 	* 10:  "K-12 student"
# 	* 11:  "lawyer"
# 	* 12:  "programmer"
# 	* 13:  "retired"
# 	* 14:  "sales/marketing"
# 	* 15:  "scientist"
# 	* 16:  "self-employed"
# 	* 17:  "technician/engineer"
# 	* 18:  "tradesman/craftsman"
# 	* 19:  "unemployed"
# 	* 20:  "writer"
#
# MOVIES FILE DESCRIPTION
# ================================================================================
#
# Movie information is in the file "movies.dat" and is in the following
# format:
#
# MovieID::Title::Genres
#
# - Titles are identical to titles provided by the IMDB (including
# year of release)
# - Genres are pipe-separated and are selected from the following genres:
#
# 	* Action
# 	* Adventure
# 	* Animation
# 	* Children's
# 	* Comedy
# 	* Crime
# 	* Documentary
# 	* Drama
# 	* Fantasy
# 	* Film-Noir
# 	* Horror
# 	* Musical
# 	* Mystery
# 	* Romance
# 	* Sci-Fi
# 	* Thriller
# 	* War
# 	* Western
#
# - Some MovieIDs do not correspond to a movie due to accidental duplicate
# entries and/or test entries
# - Movies are mostly entered by hand, so errors and inconsistencies may exist
